# %%
import os
import random

import pandas as pd
from bertopic import BERTopic
from nltk.tokenize import word_tokenize
from utils.filemanagement import load_from_file
from utils.filemanagement import get_project_root

# %%
model_type="bertopic"
model_name="BERTopic"
experiment="preliminary"
embedding_model = "preliminary"
data_type="np_mini_raw"
file_name_data = f"{data_type}.csv"
file_name = f"{model_type}_{embedding_model}_{data_type}"
folder_path_topics = f"preprocessed_data/results"
folder_path_data =f"preprocessed_data"
df = load_from_file(folder_path_data,file_name_data)
TOPN = 20
folder_path_word_cloud = f"preprocessed_data/wordclouds/{experiment}/{file_name}"

folder_name = f"Preliminary-experiment/models/{model_type}"

ROOT_PATH = get_project_root()
file_path = os.path.join(ROOT_PATH,folder_name,file_name)

print(file_path)

random_sample = False
seed = 42
# Out:
# C:\Users\Marimba\git\to_desktop\Preliminary-experiment/models/bertopic\bertopic_preliminary_np_mini_raw

# %%
data = df.text.values.tolist()
timestamps = df.date.values.tolist()
new_data = []
for item in data:
    new_data.append(str(item))

# %%
print(file_path)
# Out:
# C:\Users\Marimba\git\to_desktop\Preliminary-experiment/models/bertopic\bertopic_preliminary_np_mini_raw

# %%
topic_model = BERTopic()
try:
    topic_model = topic_model.load(file_path)
except:
    print("correctly")
    topics,probs = topic_model.fit_transform(documents=new_data)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                               Name
# 0      -1   2179                    -1_det_er_og_at
# 1       0    149                   0_barn_og_er_for
# 2       1    125                   1_og_for_til_det
# 3       2    111        2_det_arbeiderpartiet_og_er
# 4       3    100             3_statsrden_at_det_jeg
# 5       4     77                    4_det_er_som_og
# 6       5     72   5_vegne_meg_representantene_selv
# 7       6     71                    6_av_og_for_til
# 8       7     56     7_forslag_stemme_jeg_forslaget
# 9       8     50                    8_det_er_vi_har
# 10      9     45                     9_det_er_at_vi
# 11     10     43          10_kr_mill_milliarder_det
# 12     11     43                   11_og_for_er_det
# 13     12     39                   12_og_en_jeg_til
# 14     13     27       13_representanten_som_det_at
# 15     14     26      14_finansministeren_er_det_at
# 16     15     26                   15_at_som_det_en
# 17     16     24                   16_det_er_at_som
# 18     17     23                 17_nato_usa_at_det
# 19     18     23                  18_det_har_som_er
# 20     19     23               19_tiltak_til_vi_for
# 21     20     22                   20_fly_at_er_det
# 22     21     22                  21_me_ein_dei_det
# 23     22     21    22_sprsml_flgende_statsrden_til
# 24     23     20          23_politiet_etiopia_er_en
# 25     24     20            24_afghanistan_og_er_vi
# 26     25     17                    25_at_det_er_og
# 27     26     16     26_helseministeren_jeg_for_det
# 28     27     16    27_skolesekken_og_kulturelle_er
# 29     28     16                28_ein_eg_eit_ikkje
# 30     29     14         29_me_transportplan_og_for
# 31     30     14           30_statsrden_blir_har_at
# 32     31     13      31_jeg_tilbake_den_erklringen
# 33     32     13                 32_tvang_og_av_for
# 34     33     12             33_kirken_kirke_og_det
# 35     34     12                  34_det_jeg_som_er
# 36     35     10  35_fremskrittspartiet_har_som_fra
# 37     36     10                   36_det_er_vi_har

# %%
topics = topic_model.get_topics()

# %%
topic_model.visualize_topics()
# Out:
# <div>                            <div id="1810fcee-f42b-4703-ae80-c6915902e673" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1810fcee-f42b-4703-ae80-c6915902e673")) {                    Plotly.newPlot(                        "1810fcee-f42b-4703-ae80-c6915902e673",                        [{"customdata":[[0,"barn | og | er | for | at",149],[1,"og | for | til | det | at",125],[2,"det | arbeiderpartiet | og | er | at",111],[3,"statsrden | at | det | jeg | man",100],[4,"det | er | som | og | har",77],[5,"vegne | meg | representantene | selv | forslag",72],[6,"av | og | for | til | er",71],[7,"forslag | stemme | jeg | forslaget | vil",56],[8,"det | er | vi | har | at",50],[9,"det | er | at | vi | har",45],[10,"kr | mill | milliarder | det | til",43],[11,"og | for | er | det | som",43],[12,"og | en | jeg | til | har",39],[13,"representanten | som | det | at | har",27],[14,"finansministeren | er | det | at | for",26],[15,"at | som | det | en | er",26],[16,"det | er | at | som | jeg",24],[17,"nato | usa | at | det | ein",23],[18,"det | har | som | er | vi",23],[19,"tiltak | til | vi | for | og",23],[20,"fly | at | er | det | ikke",22],[21,"me | ein | dei | det | ikkje",22],[22,"sprsml | flgende | statsrden | til | miljvernministeren",21],[23,"politiet | etiopia | er | en | og",20],[24,"afghanistan | og | er | vi | det",20],[25,"at | det | er | og | ikke",17],[26,"helseministeren | jeg | for | det | at",16],[27,"skolesekken | og | kulturelle | er | som",16],[28,"ein | eg | eit | ikkje | og",16],[29,"me | transportplan | og | for | det",14],[30,"statsrden | blir | har | at | kan",14],[31,"jeg | tilbake | den | erklringen | kan",13],[32,"tvang | og | av | for | at",13],[33,"kirken | kirke | og | det | som",12],[34,"det | jeg | som | er | den",12],[35,"fremskrittspartiet | har | som | fra | det",10],[36,"det | er | vi | har | ein",10]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[149,125,111,100,77,72,71,56,50,45,43,43,39,27,26,26,24,23,23,23,22,22,21,20,20,17,16,16,16,14,14,13,13,12,12,10,10],"sizemode":"area","sizeref":0.093125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-10.753162384033203,-10.069221496582031,-10.289527893066406,-0.13760006427764893,-10.392195701599121,-0.6595920920372009,-10.329486846923828,25.484525680541992,0.6747226715087891,0.39657244086265564,-0.42832785844802856,-10.680103302001953,-0.09226404875516891,6.010794639587402,6.8270583152771,-0.20958870649337769,7.528570652008057,10.925287246704102,6.767470359802246,6.8020477294921875,5.846444606781006,16.75755500793457,25.788461685180664,10.59887409210205,10.915752410888672,7.431567192077637,5.875372886657715,7.013842582702637,16.75755500793457,6.6854095458984375,25.355670928955078,25.446670532226562,10.716336250305176,6.530452728271484,7.305598258972168,-0.5228252410888672,7.463149070739746],"xaxis":"x","y":[4.374216556549072,4.489295959472656,4.738583564758301,2.8246469497680664,4.645400047302246,1.939907431602478,4.987252712249756,-2.204503297805786,2.2095558643341064,2.405229330062866,2.6133482456207275,4.94372034072876,2.3860363960266113,11.157038688659668,12.244243621826172,2.433223247528076,10.696817398071289,-5.456513404846191,10.619898796081543,11.904496192932129,11.232226371765137,14.081683158874512,-1.9076776504516602,-5.130030632019043,-5.446990966796875,10.03952407836914,11.603543281555176,11.98190689086914,14.08166790008545,10.913773536682129,-2.3367741107940674,-2.243830680847168,-5.2475080490112305,10.741039276123047,10.462316513061523,2.10500168800354,9.953173637390137],"yaxis":"y","type":"scatter"}],                        {"t ...

# %%
topic_model.save(file_path)

# %%
topics
# Out:
# {-1: [('det', 0.021118887153942605),
#   ('er', 0.019732953082395623),
#   ('og', 0.01884634369083964),
#   ('at', 0.01868711324623471),
#   ('som', 0.018134267431320128),
#   ('til', 0.01671081780776602),
#   ('for', 0.01622127320627951),
#   ('vi', 0.016163736474778218),
#   ('har', 0.01613647511842628),
#   ('en', 0.015396528652337739)],
#  0: [('barn', 0.03084674992464337),
#   ('og', 0.020663198487011238),
#   ('er', 0.019956474959667864),
#   ('for', 0.019711430583671273),
#   ('at', 0.01938452501631019),
#   ('det', 0.019113865241205376),
#   ('som', 0.018857588082288785),
#   ('til', 0.017473761353217557),
#   ('har', 0.016967942495026565),
#   ('vi', 0.01578569101295868)],
#  1: [('og', 0.020753009934444986),
#   ('for', 0.01858177906202487),
#   ('til', 0.018279508800585965),
#   ('det', 0.01817992773027558),
#   ('at', 0.017682642929741837),
#   ('er', 0.017594355940302054),
#   ('som', 0.015869544946903957),
#   ('av', 0.015457319317081407),
#   ('en', 0.015285533327932138),
#   ('har', 0.014817456969070957)],
#  2: [('det', 0.01962390150335847),
#   ('arbeiderpartiet', 0.01911469172117203),
#   ('og', 0.01890002683585865),
#   ('er', 0.01877522391938632),
#   ('at', 0.01819358186360985),
#   ('for', 0.01765649672809117),
#   ('som', 0.017629682204709445),
#   ('til', 0.016073780203905687),
#   ('har', 0.01607338241411066),
#   ('en', 0.015330968076629118)],
#  3: [('statsrden', 0.03139940406948865),
#   ('at', 0.020888485317175447),
#   ('det', 0.019353839079961764),
#   ('jeg', 0.01868273587647009),
#   ('man', 0.01842983104096133),
#   ('har', 0.017771056569429847),
#   ('til', 0.0176795075939313),
#   ('og', 0.017668375498370543),
#   ('er', 0.017539031279858768),
#   ('som', 0.017074431535670863)],
#  4: [('det', 0.021418667707146444),
#   ('er', 0.02037658575905001),
#   ('som', 0.019570953870895986),
#   ('og', 0.0187518398395585),
#   ('har', 0.017679685265160797),
#   ('for', 0.017368378913568332),
#   ('at', 0.01672692272641283),
#   ('til', 0.016078192960256275),
#   ('de', 0.015387221978443227),
#   ('en', 0.015256197455888633)],
#  5: [('vegne', 0.14774520050311526),
#   ('meg', 0.10143344986253364),
#   ('representantene', 0.0928585522631327),
#   ('selv', 0.09011737783590379),
#   ('forslag', 0.07809694313175514),
#   ('fremme', 0.06938253694175082),
#   ('av', 0.06080187509624701),
#   ('om', 0.04997032101818809),
#   ('representantforslag', 0.04927553170362215),
#   ('stortingsrepresentantene', 0.04575585086764914)],
#  6: [('av', 0.021060005982293604),
#   ('og', 0.01954383106654446),
#   ('for', 0.019132223354058994),
#   ('til', 0.018467395378260382),
#   ('er', 0.01796694325715032),
#   ('at', 0.017717944706252133),
#   ('har', 0.015609969416279151),
#   ('en', 0.015451289494966493),
#   ('det', 0.015300821001758124),
#   ('med', 0.015175421038488101)],
#  7: [('forslag', 0.06653691739280249),
#   ('stemme', 0.05142736311669918),
#   ('jeg', 0.04034418144196278),
#   ('forslaget', 0.03963238866122253),
#   ('vil', 0.03669270467176695),
#   ('nr', 0.029545502891024422),
#   ('svs', 0.029094805455720303),
#   ('presidenten', 0.0272406916773412),
#   ('stemmer', 0.026758969283659218),
#   ('vi', 0.026649990743381063)],
#  8: [('det', 0.02463177647482582),
#   ('er', 0.021430795910593933),
#   ('vi', 0.02110641428646287),
#   ('har', 0.020185742132873406),
#   ('at', 0.018399477894151774),
#   ('og', 0.01791591909804988),
#   ('som', 0.01771076334525743),
#   ('jeg', 0.017419641446572768),
#   ('til', 0.0165754561261667),
#   ('av', 0.015330486612554385)],
#  9: [('det', 0.023703752501087135),
#   ('er', 0.021849968011653134),
#   ('at', 0.0190460745333261),
#   ('vi', 0.01860775381017669),
#   ('har', 0.018024357450764555),
#   ('og', 0.017347761566054526),
#   ('som', 0.017187802650946337),
#   ('til', 0.01705700316499338),
#   ('de', 0.016136574686695746),
#   ('for', 0.016102399053990604)],
#  10: [('kr', 0.03738313601499692),
#   ('mill', 0.026223320491918986),
#   ('milliarder', 0.021572893447716127),
#   ('det', 0.020094043205437454),
#   ('til', 0.01938369706007628),
#   ('at', 0.01892495753450244),
#   ('og', 0.018829333796238024),
#   ('er', 0.01791907007298087),
#   ('som', 0.016359344721896242),
#   ('har', 0.01617545497137332)],
#  11: [('og', 0.023927172140292156),
#   ('for', 0.01973741725493118),
#   ('er', 0.019120926862227897),
#   ('det', 0.017968817994779437),
#   ('som', 0.01782423903815899),
#   ('av', 0.016866873720274858),
#   ('til', 0.016106602956946287),
#   ('at', 0.014563063353092449),
#   ('har', 0.014275381283854085),
#   ('en', 0.013539507493556662)],
#  12: [('og', 0.022355801421733802),
#   ('en', 0.019404261400107634),
#   ('jeg', 0.019144038052886128),
#   ('til', 0.019081470228029425),
#   ('har', 0.018903410783971186),
#   ('det', 0.018771867933884766),
#   ('som', 0.01814469534765257),
#   ('for', 0.01805324321570773),
#   ('studenter', 0.017917842703681783),
#   ('de', 0.017450071051277882)],
#  13: [('representanten', 0.03793845949474295),
#   ('som', 0.02090161170468673),
#   ('det', 0.020701688445632506),
#   ('at', 0.02061555108882356),
#   ('har', 0.01942282011536618),
#   ('til', 0.018529727149832233),
#   ('vi', 0.01804708456450261),
#   ('er', 0.017968139057731123),
#   ('og', 0.016654607155365462),
#   ('om', 0.01605436879816937)],
#  14: [('finansministeren', 0.05251257117294241),
#   ('er', 0.020691008332071024),
#   ('det', 0.020365243938989027),
#   ('at', 0.02012462663552679),
#   ('for', 0.019721341694181868),
#   ('og', 0.0179301255699454),
#   ('den', 0.0177333099082116),
#   ('har', 0.0167036071203206),
#   ('til', 0.016568459865334527),
#   ('som', 0.016250248595494017)],
#  15: [('at', 0.02051155174129179),
#   ('som', 0.020472812723784872),
#   ('det', 0.01978908064566682),
#   ('en', 0.019175161423609494),
#   ('er', 0.01768141936663075),
#   ('man', 0.01741089184335426),
#   ('vi', 0.017299584906657832),
#   ('de', 0.01638514485960972),
#   ('for', 0.015846244104376975),
#   ('og', 0.015715333359242578)],
#  16: [('det', 0.02772558993693873),
#   ('er', 0.024969620354739482),
#   ('at', 0.02155450040398348),
#   ('som', 0.02051132349071146),
#   ('jeg', 0.020495372547114643),
#   ('en', 0.019231274235710038),
#   ('vi', 0.01887691342720136),
#   ('skal', 0.017924536421479304),
#   ('har', 0.017570623060474275),
#   ('man', 0.017402163622230588)],
#  17: [('nato', 0.04575886415616034),
#   ('usa', 0.023730873844797176),
#   ('at', 0.020261463149727238),
#   ('det', 0.019707247939936463),
#   ('ein', 0.019279737566766385),
#   ('vi', 0.018882633830066966),
#   ('er', 0.018542498578367022),
#   ('som', 0.018427386626307846),
#   ('og', 0.01801327611673169),
#   ('til', 0.017588667104171105)],
#  18: [('det', 0.02603779770020197),
#   ('har', 0.023999802035163414),
#   ('som', 0.023656750065938974),
#   ('er', 0.022021417968813142),
#   ('vi', 0.020558557417080698),
#   ('at', 0.02045180589455383),
#   ('dette', 0.017448909842280775),
#   ('og', 0.016758026014220315),
#   ('for', 0.015742052104834186),
#   ('til', 0.015450170028043336)],
#  19: [('tiltak', 0.02819536480720751),
#   ('til', 0.020070370595763946),
#   ('vi', 0.019319771478002234),
#   ('for', 0.01887649545554165),
#   ('og', 0.01882341103223184),
#   ('vil', 0.018727604602539655),
#   ('at', 0.017790612325121184),
#   ('som', 0.017385358974066407),
#   ('de', 0.016265374434237007),
#   ('er', 0.015965264725661038)],
#  20: [('fly', 0.022479800211631477),
#   ('at', 0.02005145061920273),
#   ('er', 0.01994233877301726),
#   ('det', 0.019688341334755787),
#   ('ikke', 0.019222878070590754),
#   ('en', 0.018780225849573094),
#   ('for', 0.018488957921594103),
#   ('som', 0.017376500205032574),
#   ('har', 0.017358741832053444),
#   ('og', 0.016811681997315097)],
#  21: [('me', 0.03302116270284323),
#   ('ein', 0.03231611365159865),
#   ('dei', 0.025976537522327568),
#   ('det', 0.02378036808921628),
#   ('ikkje', 0.021171323577176503),
#   ('er', 0.020477605581084295),
#   ('som', 0.020445595499744684),
#   ('eg', 0.019938024594553246),
#   ('til', 0.017883907959108096),
#   ('at', 0.017217025669767037)],
#  22: [('sprsml', 0.035439767065657816),
#   ('flgende', 0.03423030153153309),
#   ('statsrden', 0.02951654738807311),
#   ('til', 0.028555083477470863),
#   ('miljvernministeren', 0.026318291322619754),
#   ('stille', 0.025239229108815084),
#   ('av', 0.02434343787732654),
#   ('bemanningsnorm', 0.02341326289014734),
#   ('smkraftverk', 0.021059041164040587),
#   ('vil', 0.021012061649644323)],
#  23: [('politiet', 0.028163530666365615),
#   ('etiopia', 0.023869242345300037),
#   ('er', 0.020625049469751185),
#   ('en', 0.020410318218013174),
#   ('og', 0.01899474168505753),
#   ('av', 0.018576263616693015),
#   ('som', 0.01833942913047815),
#   ('det', 0.017910165505266605),
#   ('til', 0.016930463345595056),
#   ('for', 0.015866026674338472)],
#  24: [('afghanistan', 0.06112596962962067),
#   ('og', 0.022324408168673496),
#   ('er', 0.02106614821681435),
#   ('vi', 0.020450194577493128),
#   ('det', 0.019261435715715047),
#   ('som', 0.01835429648775644),
#   ('en', 0.018107439736720257),
#   ('den', 0.01678545879581668),
#   ('at', 0.016329571771391813),
#   ('for', 0.016019112221879267)],
#  25: [('at', 0.020457761466385897),
#   ('det', 0.01951672520175231),
#   ('er', 0.01947921338809834),
#   ('og', 0.018535191482999685),
#   ('ikke', 0.018529402186346668),
#   ('som', 0.01833942913047815),
#   ('jeg', 0.017311379932947377),
#   ('for', 0.01725031088082438),
#   ('statsrden', 0.01685235306954174),
#   ('til', 0.016512427213605053)],
#  26: [('helseministeren', 0.09188642967601053),
#   ('jeg', 0.022672000416521714),
#   ('for', 0.021820906071470157),
#   ('det', 0.02142550382038523),
#   ('at', 0.020617708655656507),
#   ('ikke', 0.0194375465132819),
#   ('er', 0.018868520531393256),
#   ('om', 0.018409090668629682),
#   ('pasienter', 0.018272461553549595),
#   ('den', 0.018034214488102066)],
#  27: [('skolesekken', 0.023418731863254175),
#   ('og', 0.023359095236187098),
#   ('kulturelle', 0.023102937312443318),
#   ('er', 0.01912202862333483),
#   ('som', 0.01882897656933635),
#   ('en', 0.018826498377749468),
#   ('for', 0.018781028122203277),
#   ('av', 0.01784206110629571),
#   ('at', 0.016122890178618746),
#   ('kvinner', 0.01596463590864142)],
#  28: [('ein', 0.03980671889046494),
#   ('eg', 0.02986332585769405),
#   ('eit', 0.027661842014240733),
#   ('ikkje', 0.02532008219718569),
#   ('og', 0.022401369930397562),
#   ('ei', 0.022177795944387672),
#   ('som', 0.02145421106631836),
#   ('det', 0.021246697880959627),
#   ('er', 0.021074225446079398),
#   ('med', 0.020910378201646568)],
#  29: [('me', 0.023310657489935313),
#   ('transportplan', 0.021553148977450896),
#   ('og', 0.020512561040364887),
#   ('for', 0.020370047955016023),
#   ('det', 0.019224024963905587),
#   ('er', 0.018418553153472614),
#   ('nasjonal', 0.018224228148516642),
#   ('til', 0.01777098280246857),
#   ('transportrer', 0.0167265870772407),
#   ('om', 0.016531847870183893)],
#  30: [('statsrden', 0.10443859005255705),
#   ('blir', 0.025346345276388026),
#   ('har', 0.02491223690516387),
#   ('at', 0.023931268975315587),
#   ('kan', 0.02205849221882375),
#   ('ting', 0.021370788392671942),
#   ('bardufoss', 0.020887555267987357),
#   ('det', 0.020818644546165034),
#   ('sellafield', 0.0197107152990137),
#   ('jeg', 0.019574497513315713)],
#  31: [('jeg', 0.036554784512818496),
#   ('tilbake', 0.028107799464812608),
#   ('den', 0.027540201040565506),
#   ('erklringen', 0.026438420039798363),
#   ('kan', 0.02621408987669635),
#   ('hundretalls', 0.0257664169872649),
#   ('vil', 0.024682843504100258),
#   ('niv', 0.023848463180093916),
#   ('er', 0.023273069751823906),
#   ('det', 0.022917670851073244)],
#  32: [('tvang', 0.027285282890118737),
#   ('og', 0.02192066910255331),
#   ('av', 0.021213514966376263),
#   ('for', 0.021000077525296888),
#   ('at', 0.017946651304991408),
#   ('er', 0.017395984773200462),
#   ('datalagringsdirektivet', 0.01672171645640396),
#   ('som', 0.01621593678758357),
#   ('dette', 0.01561265231238442),
#   ('vi', 0.015569479996845043)],
#  33: [('kirken', 0.04133140105544651),
#   ('kirke', 0.02308588232246417),
#   ('og', 0.021339376991741155),
#   ('det', 0.021146788516574994),
#   ('som', 0.01913038382534029),
#   ('den', 0.018534202317720048),
#   ('av', 0.018470575136608627),
#   ('at', 0.018025638778003287),
#   ('statsrden', 0.017774341430849678),
#   ('er', 0.017596116868511303)],
#  34: [('det', 0.023939988756926153),
#   ('jeg', 0.022052651056109627),
#   ('som', 0.02118824441095772),
#   ('er', 0.020629657389650592),
#   ('den', 0.020113225809786753),
#   ('at', 0.019561335140978842),
#   ('representanten', 0.01771796408988456),
#   ('de', 0.01768476294260607),
#   ('har', 0.017445492083573447),
#   ('ddsstraff', 0.01685789005262053)],
#  35: [('fremskrittspartiet', 0.03457255100302565),
#   ('har', 0.02151429431715852),
#   ('som', 0.021315078396051602),
#   ('fra', 0.020910015205059498),
#   ('det', 0.020645803335445866),
#   ('er', 0.020500060476039778),
#   ('de', 0.02007812571201259),
#   ('og', 0.019710114816770343),
#   ('at', 0.019636801026054904),
#   ('avgiftene', 0.01897019643411472)],
#  36: [('det', 0.028188147702517593),
#   ('er', 0.024940383434425173),
#   ('vi', 0.0199540142162326),
#   ('har', 0.01963072560998601),
#   ('ein', 0.018147138989359754),
#   ('at', 0.017820015731699272),
#   ('men', 0.017657768844803762),
#   ('dette', 0.01763061108222763),
#   ('ogs', 0.016609854901842643),
#   ('som', 0.016574859220549375)]}

# %%
NUM_TOPICS = len(topic_model.topic_sizes_.keys())-1

# %%
formatted_topics = [dict(topics[i]) for i in range(NUM_TOPICS)]

# %%
print(formatted_topics)
# Out:
# [{'barn': 0.03084674992464337, 'og': 0.020663198487011238, 'er': 0.019956474959667864, 'for': 0.019711430583671273, 'at': 0.01938452501631019, 'det': 0.019113865241205376, 'som': 0.018857588082288785, 'til': 0.017473761353217557, 'har': 0.016967942495026565, 'vi': 0.01578569101295868}, {'og': 0.020753009934444986, 'for': 0.01858177906202487, 'til': 0.018279508800585965, 'det': 0.01817992773027558, 'at': 0.017682642929741837, 'er': 0.017594355940302054, 'som': 0.015869544946903957, 'av': 0.015457319317081407, 'en': 0.015285533327932138, 'har': 0.014817456969070957}, {'det': 0.01962390150335847, 'arbeiderpartiet': 0.01911469172117203, 'og': 0.01890002683585865, 'er': 0.01877522391938632, 'at': 0.01819358186360985, 'for': 0.01765649672809117, 'som': 0.017629682204709445, 'til': 0.016073780203905687, 'har': 0.01607338241411066, 'en': 0.015330968076629118}, {'statsrden': 0.03139940406948865, 'at': 0.020888485317175447, 'det': 0.019353839079961764, 'jeg': 0.01868273587647009, 'man': 0.01842983104096133, 'har': 0.017771056569429847, 'til': 0.0176795075939313, 'og': 0.017668375498370543, 'er': 0.017539031279858768, 'som': 0.017074431535670863}, {'det': 0.021418667707146444, 'er': 0.02037658575905001, 'som': 0.019570953870895986, 'og': 0.0187518398395585, 'har': 0.017679685265160797, 'for': 0.017368378913568332, 'at': 0.01672692272641283, 'til': 0.016078192960256275, 'de': 0.015387221978443227, 'en': 0.015256197455888633}, {'vegne': 0.14774520050311526, 'meg': 0.10143344986253364, 'representantene': 0.0928585522631327, 'selv': 0.09011737783590379, 'forslag': 0.07809694313175514, 'fremme': 0.06938253694175082, 'av': 0.06080187509624701, 'om': 0.04997032101818809, 'representantforslag': 0.04927553170362215, 'stortingsrepresentantene': 0.04575585086764914}, {'av': 0.021060005982293604, 'og': 0.01954383106654446, 'for': 0.019132223354058994, 'til': 0.018467395378260382, 'er': 0.01796694325715032, 'at': 0.017717944706252133, 'har': 0.015609969416279151, 'en': 0.015451289494966493, 'det': 0.015300821001758124, 'med': 0.015175421038488101}, {'forslag': 0.06653691739280249, 'stemme': 0.05142736311669918, 'jeg': 0.04034418144196278, 'forslaget': 0.03963238866122253, 'vil': 0.03669270467176695, 'nr': 0.029545502891024422, 'svs': 0.029094805455720303, 'presidenten': 0.0272406916773412, 'stemmer': 0.026758969283659218, 'vi': 0.026649990743381063}, {'det': 0.02463177647482582, 'er': 0.021430795910593933, 'vi': 0.02110641428646287, 'har': 0.020185742132873406, 'at': 0.018399477894151774, 'og': 0.01791591909804988, 'som': 0.01771076334525743, 'jeg': 0.017419641446572768, 'til': 0.0165754561261667, 'av': 0.015330486612554385}, {'det': 0.023703752501087135, 'er': 0.021849968011653134, 'at': 0.0190460745333261, 'vi': 0.01860775381017669, 'har': 0.018024357450764555, 'og': 0.017347761566054526, 'som': 0.017187802650946337, 'til': 0.01705700316499338, 'de': 0.016136574686695746, 'for': 0.016102399053990604}, {'kr': 0.03738313601499692, 'mill': 0.026223320491918986, 'milliarder': 0.021572893447716127, 'det': 0.020094043205437454, 'til': 0.01938369706007628, 'at': 0.01892495753450244, 'og': 0.018829333796238024, 'er': 0.01791907007298087, 'som': 0.016359344721896242, 'har': 0.01617545497137332}, {'og': 0.023927172140292156, 'for': 0.01973741725493118, 'er': 0.019120926862227897, 'det': 0.017968817994779437, 'som': 0.01782423903815899, 'av': 0.016866873720274858, 'til': 0.016106602956946287, 'at': 0.014563063353092449, 'har': 0.014275381283854085, 'en': 0.013539507493556662}, {'og': 0.022355801421733802, 'en': 0.019404261400107634, 'jeg': 0.019144038052886128, 'til': 0.019081470228029425, 'har': 0.018903410783971186, 'det': 0.018771867933884766, 'som': 0.01814469534765257, 'for': 0.01805324321570773, 'studenter': 0.017917842703681783, 'de': 0.017450071051277882}, {'representanten': 0.03793845949474295, 'som': 0.02090161170468673, 'det': 0.020701688445632506, 'at': 0.02061555108882356, 'har': 0.01942282011536618, 'til': 0.018529727149832233, 'vi': 0.018047084 ...

# %%
from utils.tables_and_plots import display_n_wordclouds

wordcloud = display_n_wordclouds(formatted_topics, f"{model_name}-{embedding_model}: {data_type}", NUM_TOPICS, dpi=200)

# %%
from utils.filemanagement import make_excerpt_wordcloud


excerpt_wordcloud = make_excerpt_wordcloud(formatted_topics,NUM_TOPICS,f"Sample from {model_name}-{embedding_model}: {data_type}",random_sample=random_sample,seed=seed)

excerpt_wordcloud.savefig(os.path.join(ROOT_PATH,folder_path_word_cloud,f"{file_name}_wordcloud_sample"),bbox_inches="tight")

# %%
from utils.tables_and_plots import create_wordcloud


wordcloud.savefig(os.path.join(ROOT_PATH,folder_path_word_cloud,f"{file_name}_wordcloud"))
file_name_model = "wordcloud"
for i in range(NUM_TOPICS):
    topic_wordcloud = create_wordcloud(dict(topics[i]))
    topic_wordcloud.to_file(os.path.join(ROOT_PATH, folder_path_word_cloud, str(file_name_model + f"_{i}.png")))

# %%
from utils.filemanagement import write_topics_file
topic_words_numbered = []
for i, key in enumerate(topics.keys()):
    if key == -1:
        continue
    r = topics[key]
    rr = []
    for item in r:
        rr.append(item[0])
    topic_words_numbered.append((i,rr))


write_topics_file(folder_path_topics, file_name, topic_words_numbered)

# %%
from utils.filemanagement import load_model_topics


loaded_topics = load_model_topics(folder_path_topics, file_name)

# %%
folder_path_frequencies = r"preprocessed_data/stats"
file_name_co_frequencies = f"{data_type}_co_freq"
file_name_frequencies=f"{data_type}_freq"

# %%
from utils.filemanagement import load_word_frequencies

word_frequencies = load_word_frequencies(folder_path_frequencies, file_name_frequencies)

# %%
from utils.filemanagement import load_zipped_word_co_frequencies

word_co_frequencies = load_zipped_word_co_frequencies(folder_path_frequencies,file_name_co_frequencies)

# %%
from utils.stats import compute_metrics

coherence, diversity = compute_metrics(
    loaded_topics.values(), word_frequencies, word_co_frequencies, 10)
# Out:
# 10
# ('barn', 'og') wordtuple
# ('barn', 'og') wordup
# 19611.0 over
# 27407592.0 under
# -10.448696761832137 -14.259375482558218 0.7327597744103711 ('barn', 'og') 19611 892 30726
# ('barn', 'er') wordtuple
# ('barn', 'er') wordup
# 17962.0 over
# 29960496.0 under
# -10.703897795067089 -14.132660377147287 0.7573873219493369 ('barn', 'er') 17962 892 33588
# ('barn', 'for') wordtuple
# ('barn', 'for') wordup
# 12203.0 over
# 17244144.0 under
# -10.464654934545807 -13.574948244802224 0.7708799139291502 ('barn', 'for') 12203 892 19332
# ('at', 'barn') wordtuple
# ('at', 'barn') wordup
# 13994.0 over
# 24248128.0 under
# -10.75884926078977 -13.772520776314755 0.7811822857651639 ('at', 'barn') 13994 892 27184
# ('barn', 'det') wordtuple
# ('barn', 'det') wordup
# 19157.0 over
# 38005444.0 under
# -10.954118721782235 -14.225584031229202 0.7700294552220022 ('barn', 'det') 19157 892 42607
# ('barn', 'som') wordtuple
# ('barn', 'som') wordup
# 14042.0 over
# 22013668.0 under
# -10.614435404064055 -13.777460812669785 0.7704202935785522 ('barn', 'som') 14042 892 24679
# ('barn', 'til') wordtuple
# ('barn', 'til') wordup
# 11319.0 over
# 17726716.0 under
# -10.612963070171036 -13.466458885531265 0.7881034769707644 ('barn', 'til') 11319 892 19873
# ('barn', 'har') wordtuple
# ('barn', 'har') wordup
# 8561.0 over
# 15827648.0 under
# -10.852379939497023 -13.06356361058499 0.8307365633909942 ('barn', 'har') 8561 892 17744
# ('barn', 'vi') wordtuple
# ('barn', 'vi') wordup
# 8188.0 over
# 14403124.0 under
# -10.780583039584629 -12.99929538702341 0.829320568432223 ('barn', 'vi') 8188 892 16147
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 30726 33588
# ('for', 'og') wordtuple
# ('for', 'og') wordup
# 339800.0 over
# 593995032.0 under
# -10.771549296938831 -18.374326326958943 0.5862282570400819 ('for', 'og') 339800 30726 19332
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 30726 27184
# ('det', 'og') wordtuple
# ('det', 'og') wordup
# 678738.0 over
# 1309142682.0 under
# -10.913479936643508 -19.372495260917674 0.5633492118416209 ('det', 'og') 678738 30726 42607
# ('og', 'som') wordtuple
# ('og', 'som') wordup
# 414423.0 over
# 758286954.0 under
# -10.837424113684415 -18.660744547599172 0.5807605417908537 ('og', 'som') 414423 30726 24679
# ('og', 'til') wordtuple
# ('og', 'til') wordup
# 333862.0 over
# 610617798.0 under
# -10.83680202987262 -18.348892370379428 0.5905970677209075 ('og', 'til') 333862 30726 19873
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# -10.903644927541992 -18.118571067089768 0.6017938659272732 ('har', 'og') 284599 30726 17744
# ('og', 'vi') wordtuple
# ('og', 'vi') wordup
# 278323.0 over
# 496132722.0 under
# -10.799750261982966 -18.08640060917482 0.5971199297943505 ('og', 'vi') 278323 30726 16147
# ('er', 'for') wordtuple
# ('er', 'for') wordup
# 343735.0 over
# 649323216.0 under
# -10.883424319099326 -18.39093723262247 0.5917819294056389 ('er', 'for') 343735 33588 19332
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 33588 27184
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 33588 42607
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 33588 24679
# ('er', 'til') wordtuple
# ('er', 'til') wordup
# 338623.0 over
# 667494324.0 under
# -10.944859886138072 -18.369320441937997 0.5958227970780268 ('er', 'til') 338623 33588 19873
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 33588 17744
# ('er', 'vi') wordtuple
# ('er', 'vi') wordup
# 298629.0 over
# 542345436.0 under
# -10.826642051488284 -18.187994747493523 0.5952630953437182 ('er', 'vi') 298629 33588 16147
# ('at', 'for') wordtuple
# ('at', 'for') wordup
# 267374.0 over
# 525521088.0 under
# -10.940673760568783 -18.028499656043163 0.6068543677677285 ('at', 'for') 267374 19332 27184
# ('det', 'for') wordtuple
# ('det', 'for') wordup
# 419989.0 over
# 823678524.0 under
# -10.937514115555574 -18.679992016963283 0.5855202778257736 ('det', 'for') 419989 19332 42607
# ('for', 'som') wordtuple
# ('for', 'som') wordup
# 256315.0 over
# 477094428.0 under
# -10.86214121167912 -17.96755838456214 0.6045418625722654 ('for', 'som') 256315 19332 24679
# ('for', 'til') wordtuple
# ('for', 'til') wordup
# 207185.0 over
# 384184836.0 under
# -10.85666530373767 -17.660560031472055 0.6147407151523233 ('for', 'til') 207185 19332 19873
# ('for', 'har') wordtuple
# ('for', 'har') wordup
# 176959.0 over
# 343027008.0 under
# -10.92069131715225 -17.433055612437183 0.6264358675802739 ('for', 'har') 176959 19332 17744
# ('for', 'vi') wordtuple
# ('for', 'vi') wordup
# 170689.0 over
# 312153804.0 under
# -10.836671244354566 -17.381010561760895 0.6234776284064744 ('for', 'vi') 170689 19332 16147
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 27184 42607
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 27184 24679
# ('at', 'til') wordtuple
# ('at', 'til') wordup
# 268936.0 over
# 540227632.0 under
# -10.972088830015718 -18.0369033629505 0.6083133345690271 ('at', 'til') 268936 27184 19873
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 27184 17744
# ('at', 'vi') wordtuple
# ('at', 'vi') wordup
# 232152.0 over
# 438940048.0 under
# -10.884738479593876 -17.82471018427808 0.610654443582176 ('at', 'vi') 232152 27184 16147
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 42607 24679
# ('det', 'til') wordtuple
# ('det', 'til') wordup
# 420710.0 over
# 846728911.0 under
# -10.974858324009793 -18.682466584863334 0.5874416139944658 ('det', 'til') 420710 42607 19873
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 42607 17744
# ('det', 'vi') wordtuple
# ('det', 'vi') wordup
# 376531.0 over
# 687975229.0 under
# -10.83537225769542 -18.522409122083445 0.5849872004380298 ('det', 'vi') 376531 42607 16147
# ('som', 'til') wordtuple
# ('som', 'til') wordup
# 255496.0 over
# 490445767.0 under
# -10.906577193396357 -17.962941179199174 0.6071710130647211 ('som', 'til') 255496 24679 19873
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 24679 17744
# ('som', 'vi') wordtuple
# ('som', 'vi') wordup
# 221603.0 over
# 398491813.0 under
# -10.812356956739512 -17.75761788676176 0.6088855512990897 ('som', 'vi') 221603 24679 16147
# ('har', 'til') wordtuple
# ('har', 'til') wordup
# 177605.0 over
# 352626512.0 under
# -10.955253033976165 -17.43831267196754 0.6282289599949064 ('har', 'til') 177605 19873 17744
# ('til', 'vi') wordtuple
# ('til', 'vi') wordup
# 171610.0 over
# 320889331.0 under
# -10.868726484507468 -17.388774097962266 0.6250427099275008 ('til', 'vi') 171610 19873 16147
# ('har', 'vi') wordtuple
# ('har', 'vi') wordup
# 159145.0 over
# 286512368.0 under
# -10.814039871159938 -17.279982305689508 0.6258131333617957 ('har', 'vi') 159145 17744 16147
# 57.02562406493147 2v
# 90 x2
# 90
# 0.6336180451659053 n printed
# 10
# ('for', 'og') wordtuple
# ('for', 'og') wordup
# 339800.0 over
# 593995032.0 under
# -10.771549296938831 -18.374326326958943 0.5862282570400819 ('for', 'og') 339800 30726 19332
# ('og', 'til') wordtuple
# ('og', 'til') wordup
# 333862.0 over
# 610617798.0 under
# -10.83680202987262 -18.348892370379428 0.5905970677209075 ('og', 'til') 333862 30726 19873
# ('det', 'og') wordtuple
# ('det', 'og') wordup
# 678738.0 over
# 1309142682.0 under
# -10.913479936643508 -19.372495260917674 0.5633492118416209 ('det', 'og') 678738 30726 42607
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 30726 27184
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 30726 33588
# ('og', 'som') wordtuple
# ('og', 'som') wordup
# 414423.0 over
# 758286954.0 under
# -10.837424113684415 -18.660744547599172 0.5807605417908537 ('og', 'som') 414423 30726 24679
# ('av', 'og') wordtuple
# ('av', 'og') wordup
# 240906.0 over
# 417381984.0 under
# -10.758682287828702 -17.87811080019439 0.6017795956221349 ('av', 'og') 240906 30726 13584
# ('en', 'og') wordtuple
# ('en', 'og') wordup
# 252623.0 over
# 458892810.0 under
# -10.826955492304773 -17.94662646936343 0.6032863898286064 ('en', 'og') 252623 30726 14935
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# -10.903644927541992 -18.118571067089768 0.6017938659272732 ('har', 'og') 284599 30726 17744
# ('for', 'til') wordtuple
# ('for', 'til') wordup
# 207185.0 over
# 384184836.0 under
# -10.85666530373767 -17.660560031472055 0.6147407151523233 ('for', 'til') 207185 19332 19873
# ('det', 'for') wordtuple
# ('det', 'for') wordup
# 419989.0 over
# 823678524.0 under
# -10.937514115555574 -18.679992016963283 0.5855202778257736 ('det', 'for') 419989 19332 42607
# ('at', 'for') wordtuple
# ('at', 'for') wordup
# 267374.0 over
# 525521088.0 under
# -10.940673760568783 -18.028499656043163 0.6068543677677285 ('at', 'for') 267374 19332 27184
# ('er', 'for') wordtuple
# ('er', 'for') wordup
# 343735.0 over
# 649323216.0 under
# -10.883424319099326 -18.39093723262247 0.5917819294056389 ('er', 'for') 343735 19332 33588
# ('for', 'som') wordtuple
# ('for', 'som') wordup
# 256315.0 over
# 477094428.0 under
# -10.86214121167912 -17.96755838456214 0.6045418625722654 ('for', 'som') 256315 19332 24679
# ('av', 'for') wordtuple
# ('av', 'for') wordup
# 149947.0 over
# 262605888.0 under
# -10.774230890148026 -17.194093132832737 0.62662396945927 ('av', 'for') 149947 19332 13584
# ('en', 'for') wordtuple
# ('en', 'for') wordup
# 156624.0 over
# 288723420.0 under
# -10.848167123812859 -17.256945772813022 0.6286261350431606 ('en', 'for') 156624 19332 14935
# ('for', 'har') wordtuple
# ('for', 'har') wordup
# 176959.0 over
# 343027008.0 under
# -10.92069131715225 -17.433055612437183 0.6264358675802739 ('for', 'har') 176959 19332 17744
# ('det', 'til') wordtuple
# ('det', 'til') wordup
# 420710.0 over
# 846728911.0 under
# -10.974858324009793 -18.682466584863334 0.5874416139944658 ('det', 'til') 420710 19873 42607
# ('at', 'til') wordtuple
# ('at', 'til') wordup
# 268936.0 over
# 540227632.0 under
# -10.972088830015718 -18.0369033629505 0.6083133345690271 ('at', 'til') 268936 19873 27184
# ('er', 'til') wordtuple
# ('er', 'til') wordup
# 338623.0 over
# 667494324.0 under
# -10.944859886138072 -18.369320441937997 0.5958227970780268 ('er', 'til') 338623 19873 33588
# ('som', 'til') wordtuple
# ('som', 'til') wordup
# 255496.0 over
# 490445767.0 under
# -10.906577193396357 -17.962941179199174 0.6071710130647211 ('som', 'til') 255496 19873 24679
# ('av', 'til') wordtuple
# ('av', 'til') wordup
# 148774.0 over
# 269954832.0 under
# -10.825379904289203 -17.18276289504583 0.6300139256074121 ('av', 'til') 148774 19873 13584
# ('en', 'til') wordtuple
# ('en', 'til') wordup
# 154967.0 over
# 296803255.0 under
# -10.90333017017361 -17.24160150280654 0.6323850002216324 ('en', 'til') 154967 19873 14935
# ('har', 'til') wordtuple
# ('har', 'til') wordup
# 177605.0 over
# 352626512.0 under
# -10.955253033976165 -17.43831267196754 0.6282289599949064 ('har', 'til') 177605 19873 17744
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 42607 27184
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 42607 33588
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 42607 24679
# ('av', 'det') wordtuple
# ('av', 'det') wordup
# 294140.0 over
# 578773488.0 under
# -10.942280133026156 -18.166143463618013 0.6023446944003636 ('av', 'det') 294140 42607 13584
# ('det', 'en') wordtuple
# ('det', 'en') wordup
# 327979.0 over
# 636335545.0 under
# -10.92196855163643 -18.323243918652853 0.5960717763800542 ('det', 'en') 327979 42607 14935
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 42607 17744
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 27184 33588
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 27184 24679
# ('at', 'av') wordtuple
# ('at', 'av') wordup
# 188474.0 over
# 369267456.0 under
# -10.936084888950818 -17.524005991786442 0.6240630649222898 ('at', 'av') 188474 27184 13584
# ('at', 'en') wordtuple
# ('at', 'en') wordup
# 204627.0 over
# 405993040.0 under
# -10.954242762447205 -17.64263699193517 0.6208960014001663 ('at', 'en') 204627 27184 14935
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 27184 17744
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 33588 24679
# ('av', 'er') wordtuple
# ('av', 'er') wordup
# 241672.0 over
# 456259392.0 under
# -10.882588208568093 -17.88269080727902 0.608554290058989 ('av', 'er') 241672 33588 13584
# ('en', 'er') wordtuple
# ('en', 'er') wordup
# 266666.0 over
# 501636780.0 under
# -10.87739352251868 -18.024674366973546 0.6034724012795057 ('en', 'er') 266666 33588 14935
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 33588 17744
# ('av', 'som') wordtuple
# ('av', 'som') wordup
# 182557.0 over
# 335239536.0 under
# -10.842629597125919 -17.477987463240655 0.6203591586233779 ('av', 'som') 182557 24679 13584
# ('en', 'som') wordtuple
# ('en', 'som') wordup
# 200659.0 over
# 368580865.0 under
# -10.843019593942005 -17.614386340069686 0.6155774822127075 ('en', 'som') 200659 24679 14935
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 24679 17744
# ('av', 'en') wordtuple
# ('av', 'en') wordup
# 114400.0 over
# 202877040.0 under
# -10.792302834198077 -16.803727526553114 0.6422564765552267 ('av', 'en') 114400 13584 14935
# ('av', 'har') wordtuple
# ('av', 'har') wordup
# 123665.0 over
# 241034496.0 under
# -10.928586676613428 -16.91607771710132 0.646047320151832 ('av', 'har') 123665 13584 17744
# ('en', 'har') wordtuple
# ('en', 'har') wordup
# 135071.0 over
# 265006640.0 under
# -10.938094834375148 -17.043358432984714 0.6417804846025066 ('en', 'har') 135071 14935 17744
# 54.30977370606658 2v
# 90 x2
# 90
# 0.6034419300674064 n printed
# 10
# ('arbeiderpartiet', 'det') wordtuple
# ('arbeiderpartiet', 'det') wordup
# 13701.0 over
# 29995328.0 under
# -11.096240896628917 -13.74199357509951 0.8074695156847769 ('arbeiderpartiet', 'det') 13701 42607 704
# ('det', 'og') wordtuple
# ('det', 'og') wordup
# 678738.0 over
# 1309142682.0 under
# -10.913479936643508 -19.372495260917674 0.5633492118416209 ('det', 'og') 678738 42607 30726
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 42607 33588
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 42607 27184
# ('det', 'for') wordtuple
# ('det', 'for') wordup
# 419989.0 over
# 823678524.0 under
# -10.937514115555574 -18.679992016963283 0.5855202778257736 ('det', 'for') 419989 42607 19332
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 42607 24679
# ('det', 'til') wordtuple
# ('det', 'til') wordup
# 420710.0 over
# 846728911.0 under
# -10.974858324009793 -18.682466584863334 0.5874416139944658 ('det', 'til') 420710 42607 19873
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 42607 17744
# ('det', 'en') wordtuple
# ('det', 'en') wordup
# 327979.0 over
# 636335545.0 under
# -10.92196855163643 -18.323243918652853 0.5960717763800542 ('det', 'en') 327979 42607 14935
# ('arbeiderpartiet', 'og') wordtuple
# ('arbeiderpartiet', 'og') wordup
# 9403.0 over
# 21631104.0 under
# -11.167698560525443 -13.198905402581905 0.8461079324305841 ('arbeiderpartiet', 'og') 9403 704 30726
# ('arbeiderpartiet', 'er') wordtuple
# ('arbeiderpartiet', 'er') wordup
# 10023.0 over
# 23645952.0 under
# -11.204063122875242 -13.291026768056128 0.8429795017645493 ('arbeiderpartiet', 'er') 10023 704 33588
# ('arbeiderpartiet', 'at') wordtuple
# ('arbeiderpartiet', 'at') wordup
# 8703.0 over
# 19137536.0 under
# -11.102604674902365 -13.087297080919155 0.848349709359742 ('arbeiderpartiet', 'at') 8703 704 27184
# ('arbeiderpartiet', 'for') wordtuple
# ('arbeiderpartiet', 'for') wordup
# 6309.0 over
# 13609728.0 under
# -11.074939262612087 -12.623195635452937 0.8773483024779806 ('arbeiderpartiet', 'for') 6309 704 19332
# ('arbeiderpartiet', 'som') wordtuple
# ('arbeiderpartiet', 'som') wordup
# 7957.0 over
# 17374016.0 under
# -11.09241905179389 -12.958008883656943 0.8560280480887774 ('arbeiderpartiet', 'som') 7957 704 24679
# ('arbeiderpartiet', 'til') wordtuple
# ('arbeiderpartiet', 'til') wordup
# 6491.0 over
# 13990592.0 under
# -11.073728633581364 -12.664225040837929 0.8744102854988962 ('arbeiderpartiet', 'til') 6491 704 19873
# ('arbeiderpartiet', 'har') wordtuple
# ('arbeiderpartiet', 'har') wordup
# 5867.0 over
# 12491776.0 under
# -11.056067992127643 -12.518407276671365 0.8831848770994326 ('arbeiderpartiet', 'har') 5867 704 17744
# ('arbeiderpartiet', 'en') wordtuple
# ('arbeiderpartiet', 'en') wordup
# 5304.0 over
# 10514240.0 under
# -10.952976175722863 -12.372865060112588 0.8852417061455607 ('arbeiderpartiet', 'en') 5304 704 14935
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 30726 33588
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 30726 27184
# ('for', 'og') wordtuple
# ('for', 'og') wordup
# 339800.0 over
# 593995032.0 under
# -10.771549296938831 -18.374326326958943 0.5862282570400819 ('for', 'og') 339800 30726 19332
# ('og', 'som') wordtuple
# ('og', 'som') wordup
# 414423.0 over
# 758286954.0 under
# -10.837424113684415 -18.660744547599172 0.5807605417908537 ('og', 'som') 414423 30726 24679
# ('og', 'til') wordtuple
# ('og', 'til') wordup
# 333862.0 over
# 610617798.0 under
# -10.83680202987262 -18.348892370379428 0.5905970677209075 ('og', 'til') 333862 30726 19873
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# -10.903644927541992 -18.118571067089768 0.6017938659272732 ('har', 'og') 284599 30726 17744
# ('en', 'og') wordtuple
# ('en', 'og') wordup
# 252623.0 over
# 458892810.0 under
# -10.826955492304773 -17.94662646936343 0.6032863898286064 ('en', 'og') 252623 30726 14935
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 33588 27184
# ('er', 'for') wordtuple
# ('er', 'for') wordup
# 343735.0 over
# 649323216.0 under
# -10.883424319099326 -18.39093723262247 0.5917819294056389 ('er', 'for') 343735 33588 19332
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 33588 24679
# ('er', 'til') wordtuple
# ('er', 'til') wordup
# 338623.0 over
# 667494324.0 under
# -10.944859886138072 -18.369320441937997 0.5958227970780268 ('er', 'til') 338623 33588 19873
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 33588 17744
# ('en', 'er') wordtuple
# ('en', 'er') wordup
# 266666.0 over
# 501636780.0 under
# -10.87739352251868 -18.024674366973546 0.6034724012795057 ('en', 'er') 266666 33588 14935
# ('at', 'for') wordtuple
# ('at', 'for') wordup
# 267374.0 over
# 525521088.0 under
# -10.940673760568783 -18.028499656043163 0.6068543677677285 ('at', 'for') 267374 27184 19332
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 27184 24679
# ('at', 'til') wordtuple
# ('at', 'til') wordup
# 268936.0 over
# 540227632.0 under
# -10.972088830015718 -18.0369033629505 0.6083133345690271 ('at', 'til') 268936 27184 19873
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 27184 17744
# ('at', 'en') wordtuple
# ('at', 'en') wordup
# 204627.0 over
# 405993040.0 under
# -10.954242762447205 -17.64263699193517 0.6208960014001663 ('at', 'en') 204627 27184 14935
# ('for', 'som') wordtuple
# ('for', 'som') wordup
# 256315.0 over
# 477094428.0 under
# -10.86214121167912 -17.96755838456214 0.6045418625722654 ('for', 'som') 256315 19332 24679
# ('for', 'til') wordtuple
# ('for', 'til') wordup
# 207185.0 over
# 384184836.0 under
# -10.85666530373767 -17.660560031472055 0.6147407151523233 ('for', 'til') 207185 19332 19873
# ('for', 'har') wordtuple
# ('for', 'har') wordup
# 176959.0 over
# 343027008.0 under
# -10.92069131715225 -17.433055612437183 0.6264358675802739 ('for', 'har') 176959 19332 17744
# ('en', 'for') wordtuple
# ('en', 'for') wordup
# 156624.0 over
# 288723420.0 under
# -10.848167123812859 -17.256945772813022 0.6286261350431606 ('en', 'for') 156624 19332 14935
# ('som', 'til') wordtuple
# ('som', 'til') wordup
# 255496.0 over
# 490445767.0 under
# -10.906577193396357 -17.962941179199174 0.6071710130647211 ('som', 'til') 255496 24679 19873
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 24679 17744
# ('en', 'som') wordtuple
# ('en', 'som') wordup
# 200659.0 over
# 368580865.0 under
# -10.843019593942005 -17.614386340069686 0.6155774822127075 ('en', 'som') 200659 24679 14935
# ('har', 'til') wordtuple
# ('har', 'til') wordup
# 177605.0 over
# 352626512.0 under
# -10.955253033976165 -17.43831267196754 0.6282289599949064 ('har', 'til') 177605 19873 17744
# ('en', 'til') wordtuple
# ('en', 'til') wordup
# 154967.0 over
# 296803255.0 under
# -10.90333017017361 -17.24160150280654 0.6323850002216324 ('en', 'til') 154967 19873 14935
# ('en', 'har') wordtuple
# ('en', 'har') wordup
# 135071.0 over
# 265006640.0 under
# -10.938094834375148 -17.043358432984714 0.6417804846025066 ('en', 'har') 135071 17744 14935
# 58.54792847236537 2v
# 90 x2
# 90
# 0.6505325385818375 n printed
# 10
# ('at', 'statsrden') wordtuple
# ('det', 'statsrden') wordtuple
# ('jeg', 'statsrden') wordtuple
# ('man', 'statsrden') wordtuple
# ('har', 'statsrden') wordtuple
# ('statsrden', 'til') wordtuple
# ('og', 'statsrden') wordtuple
# ('er', 'statsrden') wordtuple
# ('som', 'statsrden') wordtuple
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 27184 42607
# ('at', 'jeg') wordtuple
# ('at', 'jeg') wordup
# 132918.0 over
# 298099744.0 under
# -11.131042930784485 -17.020176964696535 0.6539910221775387 ('at', 'jeg') 132918 27184 10966
# ('at', 'man') wordtuple
# ('at', 'man') wordup
# 93354.0 over
# 177756176.0 under
# -10.894900225705923 -16.510424219424916 0.6598800903545414 ('at', 'man') 93354 27184 6539
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 27184 17744
# ('at', 'til') wordtuple
# ('at', 'til') wordup
# 268936.0 over
# 540227632.0 under
# -10.972088830015718 -18.0369033629505 0.6083133345690271 ('at', 'til') 268936 27184 19873
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 27184 30726
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 27184 33588
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 27184 24679
# ('det', 'jeg') wordtuple
# ('det', 'jeg') wordup
# 212251.0 over
# 467228362.0 under
# -11.104140786039036 -17.695411825348895 0.6275152505991535 ('det', 'jeg') 212251 42607 10966
# ('det', 'man') wordtuple
# ('det', 'man') wordup
# 152097.0 over
# 278607173.0 under
# -10.839024989342647 -17.214632171695104 0.6296402317073349 ('det', 'man') 152097 42607 6539
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 42607 17744
# ('det', 'til') wordtuple
# ('det', 'til') wordup
# 420710.0 over
# 846728911.0 under
# -10.974858324009793 -18.682466584863334 0.5874416139944658 ('det', 'til') 420710 42607 19873
# ('det', 'og') wordtuple
# ('det', 'og') wordup
# 678738.0 over
# 1309142682.0 under
# -10.913479936643508 -19.372495260917674 0.5633492118416209 ('det', 'og') 678738 42607 30726
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 42607 33588
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 42607 24679
# ('jeg', 'man') wordtuple
# ('jeg', 'man') wordup
# 39129.0 over
# 71706674.0 under
# -10.839653446209308 -15.255950620034112 0.7105196992427779 ('jeg', 'man') 39129 10966 6539
# ('har', 'jeg') wordtuple
# ('har', 'jeg') wordup
# 86101.0 over
# 194580704.0 under
# -11.14205103534428 -16.393742373114225 0.6796526858697786 ('har', 'jeg') 86101 10966 17744
# ('jeg', 'til') wordtuple
# ('jeg', 'til') wordup
# 93662.0 over
# 217927318.0 under
# -11.184095589752296 -16.5151762243265 0.677201105082873 ('jeg', 'til') 93662 10966 19873
# ('jeg', 'og') wordtuple
# ('jeg', 'og') wordup
# 148241.0 over
# 336941316.0 under
# -11.15033710972746 -17.177584993039392 0.6491213470488277 ('jeg', 'og') 148241 10966 30726
# ('er', 'jeg') wordtuple
# ('er', 'jeg') wordup
# 165522.0 over
# 368326008.0 under
# -11.119744573674277 -17.336663456916593 0.6414004979278738 ('er', 'jeg') 165522 10966 33588
# ('jeg', 'som') wordtuple
# ('jeg', 'som') wordup
# 122470.0 over
# 270629914.0 under
# -11.109677207786804 -16.902068867323532 0.6572968844816948 ('jeg', 'som') 122470 10966 24679
# ('har', 'man') wordtuple
# ('har', 'man') wordup
# 60545.0 over
# 116028016.0 under
# -10.904177756096786 -15.885720202011546 0.6864138117399319 ('har', 'man') 60545 6539 17744
# ('man', 'til') wordtuple
# ('man', 'til') wordup
# 62706.0 over
# 129949547.0 under
# -11.017060490815313 -15.936315872913303 0.6913179042554516 ('man', 'til') 62706 6539 19873
# ('man', 'og') wordtuple
# ('man', 'og') wordup
# 97236.0 over
# 200917314.0 under
# -11.01282372646539 -16.56920292595128 0.6646562164566595 ('man', 'og') 97236 6539 30726
# ('er', 'man') wordtuple
# ('er', 'man') wordup
# 113406.0 over
# 219631932.0 under
# -10.919375134472112 -16.791137445768577 0.6503058634198621 ('er', 'man') 113406 6539 33588
# ('man', 'som') wordtuple
# ('man', 'som') wordup
# 86633.0 over
# 161375981.0 under
# -10.86322156820713 -16.402629056553025 0.6622853891746798 ('man', 'som') 86633 6539 24679
# ('har', 'til') wordtuple
# ('har', 'til') wordup
# 177605.0 over
# 352626512.0 under
# -10.955253033976165 -17.43831267196754 0.6282289599949064 ('har', 'til') 177605 17744 19873
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# -10.903644927541992 -18.118571067089768 0.6017938659272732 ('har', 'og') 284599 17744 30726
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 17744 33588
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 17744 24679
# ('og', 'til') wordtuple
# ('og', 'til') wordup
# 333862.0 over
# 610617798.0 under
# -10.83680202987262 -18.348892370379428 0.5905970677209075 ('og', 'til') 333862 19873 30726
# ('er', 'til') wordtuple
# ('er', 'til') wordup
# 338623.0 over
# 667494324.0 under
# -10.944859886138072 -18.369320441937997 0.5958227970780268 ('er', 'til') 338623 19873 33588
# ('som', 'til') wordtuple
# ('som', 'til') wordup
# 255496.0 over
# 490445767.0 under
# -10.906577193396357 -17.962941179199174 0.6071710130647211 ('som', 'til') 255496 19873 24679
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 30726 33588
# ('og', 'som') wordtuple
# ('og', 'som') wordup
# 414423.0 over
# 758286954.0 under
# -10.837424113684415 -18.660744547599172 0.5807605417908537 ('og', 'som') 414423 30726 24679
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 33588 24679
# 26.67168681771788 2v
# 90 x2
# 72
# 0.2963520757524209 n printed
# 10
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 42607 33588
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 42607 24679
# ('det', 'og') wordtuple
# ('det', 'og') wordup
# 678738.0 over
# 1309142682.0 under
# -10.913479936643508 -19.372495260917674 0.5633492118416209 ('det', 'og') 678738 42607 30726
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 42607 17744
# ('det', 'for') wordtuple
# ('det', 'for') wordup
# 419989.0 over
# 823678524.0 under
# -10.937514115555574 -18.679992016963283 0.5855202778257736 ('det', 'for') 419989 42607 19332
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 42607 27184
# ('det', 'til') wordtuple
# ('det', 'til') wordup
# 420710.0 over
# 846728911.0 under
# -10.974858324009793 -18.682466584863334 0.5874416139944658 ('det', 'til') 420710 42607 19873
# ('de', 'det') wordtuple
# ('de', 'det') wordup
# 216721.0 over
# 419508522.0 under
# -10.918645447298118 -17.725479430027878 0.6159859026888361 ('de', 'det') 216721 42607 9846
# ('det', 'en') wordtuple
# ('det', 'en') wordup
# 327979.0 over
# 636335545.0 under
# -10.92196855163643 -18.323243918652853 0.5960717763800542 ('det', 'en') 327979 42607 14935
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 33588 24679
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 33588 30726
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 33588 17744
# ('er', 'for') wordtuple
# ('er', 'for') wordup
# 343735.0 over
# 649323216.0 under
# -10.883424319099326 -18.39093723262247 0.5917819294056389 ('er', 'for') 343735 33588 19332
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 33588 27184
# ('er', 'til') wordtuple
# ('er', 'til') wordup
# 338623.0 over
# 667494324.0 under
# -10.944859886138072 -18.369320441937997 0.5958227970780268 ('er', 'til') 338623 33588 19873
# ('de', 'er') wordtuple
# ('de', 'er') wordup
# 174949.0 over
# 330707448.0 under
# -10.884405403865689 -17.416574892663252 0.6249452301009398 ('de', 'er') 174949 33588 9846
# ('en', 'er') wordtuple
# ('en', 'er') wordup
# 266666.0 over
# 501636780.0 under
# -10.87739352251868 -18.024674366973546 0.6034724012795057 ('en', 'er') 266666 33588 14935
# ('og', 'som') wordtuple
# ('og', 'som') wordup
# 414423.0 over
# 758286954.0 under
# -10.837424113684415 -18.660744547599172 0.5807605417908537 ('og', 'som') 414423 24679 30726
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 24679 17744
# ('for', 'som') wordtuple
# ('for', 'som') wordup
# 256315.0 over
# 477094428.0 under
# -10.86214121167912 -17.96755838456214 0.6045418625722654 ('for', 'som') 256315 24679 19332
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 24679 27184
# ('som', 'til') wordtuple
# ('som', 'til') wordup
# 255496.0 over
# 490445767.0 under
# -10.906577193396357 -17.962941179199174 0.6071710130647211 ('som', 'til') 255496 24679 19873
# ('de', 'som') wordtuple
# ('de', 'som') wordup
# 135583.0 over
# 242989434.0 under
# -10.807501568323241 -17.048816772725164 0.6339150518417894 ('de', 'som') 135583 24679 9846
# ('en', 'som') wordtuple
# ('en', 'som') wordup
# 200659.0 over
# 368580865.0 under
# -10.843019593942005 -17.614386340069686 0.6155774822127075 ('en', 'som') 200659 24679 14935
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# -10.903644927541992 -18.118571067089768 0.6017938659272732 ('har', 'og') 284599 30726 17744
# ('for', 'og') wordtuple
# ('for', 'og') wordup
# 339800.0 over
# 593995032.0 under
# -10.771549296938831 -18.374326326958943 0.5862282570400819 ('for', 'og') 339800 30726 19332
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 30726 27184
# ('og', 'til') wordtuple
# ('og', 'til') wordup
# 333862.0 over
# 610617798.0 under
# -10.83680202987262 -18.348892370379428 0.5905970677209075 ('og', 'til') 333862 30726 19873
# ('de', 'og') wordtuple
# ('de', 'og') wordup
# 169125.0 over
# 302528196.0 under
# -10.804763960066294 -17.367730408638625 0.62211720851517 ('de', 'og') 169125 30726 9846
# ('en', 'og') wordtuple
# ('en', 'og') wordup
# 252623.0 over
# 458892810.0 under
# -10.826955492304773 -17.94662646936343 0.6032863898286064 ('en', 'og') 252623 30726 14935
# ('for', 'har') wordtuple
# ('for', 'har') wordup
# 176959.0 over
# 343027008.0 under
# -10.92069131715225 -17.433055612437183 0.6264358675802739 ('for', 'har') 176959 17744 19332
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 17744 27184
# ('har', 'til') wordtuple
# ('har', 'til') wordup
# 177605.0 over
# 352626512.0 under
# -10.955253033976165 -17.43831267196754 0.6282289599949064 ('har', 'til') 177605 17744 19873
# ('de', 'har') wordtuple
# ('de', 'har') wordup
# 92031.0 over
# 174707424.0 under
# -10.890533390057756 -16.489832284338824 0.660439306008043 ('de', 'har') 92031 17744 9846
# ('en', 'har') wordtuple
# ('en', 'har') wordup
# 135071.0 over
# 265006640.0 under
# -10.938094834375148 -17.043358432984714 0.6417804846025066 ('en', 'har') 135071 17744 14935
# ('at', 'for') wordtuple
# ('at', 'for') wordup
# 267374.0 over
# 525521088.0 under
# -10.940673760568783 -18.028499656043163 0.6068543677677285 ('at', 'for') 267374 19332 27184
# ('for', 'til') wordtuple
# ('for', 'til') wordup
# 207185.0 over
# 384184836.0 under
# -10.85666530373767 -17.660560031472055 0.6147407151523233 ('for', 'til') 207185 19332 19873
# ('de', 'for') wordtuple
# ('de', 'for') wordup
# 100982.0 over
# 190342872.0 under
# -10.880286673130264 -16.623738630532333 0.6545029920734413 ('de', 'for') 100982 19332 9846
# ('en', 'for') wordtuple
# ('en', 'for') wordup
# 156624.0 over
# 288723420.0 under
# -10.848167123812859 -17.256945772813022 0.6286261350431606 ('en', 'for') 156624 19332 14935
# ('at', 'til') wordtuple
# ('at', 'til') wordup
# 268936.0 over
# 540227632.0 under
# -10.972088830015718 -18.0369033629505 0.6083133345690271 ('at', 'til') 268936 27184 19873
# ('at', 'de') wordtuple
# ('at', 'de') wordup
# 135063.0 over
# 267653664.0 under
# -10.952519179065026 -17.043272982354065 0.6426300388666446 ('at', 'de') 135063 27184 9846
# ('at', 'en') wordtuple
# ('at', 'en') wordup
# 204627.0 over
# 405993040.0 under
# -10.954242762447205 -17.64263699193517 0.6208960014001663 ('at', 'en') 204627 27184 14935
# ('de', 'til') wordtuple
# ('de', 'til') wordup
# 101586.0 over
# 195669558.0 under
# -10.9115020137286 -16.632342066288267 0.6560412219903105 ('de', 'til') 101586 19873 9846
# ('en', 'til') wordtuple
# ('en', 'til') wordup
# 154967.0 over
# 296803255.0 under
# -10.90333017017361 -17.24160150280654 0.6323850002216324 ('en', 'til') 154967 19873 14935
# ('de', 'en') wordtuple
# ('de', 'en') wordup
# 88074.0 over
# 147050010.0 under
# -10.705303072557669 -16.426428568875355 0.6517121495808272 ('de', 'en') 88074 9846 14935
# 54.630266918596774 2v
# 90 x2
# 90
# 0.6070029657621864 n printed
# 10
# ('meg', 'vegne') wordtuple
# ('meg', 'vegne') wordup
# 115.0 over
# 170352.0 under
# -10.532669308837725 -6.845490050944376 1.538628970380971 ('meg', 'vegne') 115 126 1352
# ('representantene', 'vegne') wordtuple
# ('representantene', 'vegne') wordup
# 38.0 over
# 10332.0 under
# -8.086904414674416 -5.247927513443585 1.5409710583765193 ('representantene', 'vegne') 38 126 82
# ('selv', 'vegne') wordtuple
# ('selv', 'vegne') wordup
# 89.0 over
# 139734.0 under
# -10.616590142695228 -6.475733430966398 1.639442119703015 ('selv', 'vegne') 89 126 1109
# ('forslag', 'vegne') wordtuple
# ('forslag', 'vegne') wordup
# 103.0 over
# 144270.0 under
# -10.451911279301004 -6.6865005271832185 1.5631362379782863 ('forslag', 'vegne') 103 126 1145
# ('fremme', 'vegne') wordtuple
# ('fremme', 'vegne') wordup
# 36.0 over
# 20034.0 under
# -9.12023787734196 -5.169925001442312 1.7640948127482672 ('fremme', 'vegne') 36 126 159
# ('av', 'vegne') wordtuple
# ('av', 'vegne') wordup
# 566.0 over
# 1711584.0 under
# -11.562242424221074 -9.144658242831882 1.264371189954992 ('av', 'vegne') 566 126 13584
# ('om', 'vegne') wordtuple
# ('om', 'vegne') wordup
# 359.0 over
# 1187298.0 under
# -11.691410618049986 -8.487840033823051 1.3774306032466541 ('om', 'vegne') 359 126 9423
# ('representantforslag', 'vegne') wordtuple
# ('representantforslag', 'vegne') wordup
# 11.0 over
# 3024.0 under
# -8.102810805583776 -3.4594316186372978 2.3422375982027788 ('representantforslag', 'vegne') 11 126 24
# ('stortingsrepresentantene', 'vegne') wordtuple
# ('stortingsrepresentantene', 'vegne') wordup
# 14.0 over
# 3024.0 under
# -7.754887502163469 -3.8073549220576037 2.0368175967089788 ('stortingsrepresentantene', 'vegne') 14 126 24
# ('meg', 'representantene') wordtuple
# ('meg', 'representantene') wordup
# 75.0 over
# 110864.0 under
# -10.529612750404388 -6.22881869049588 1.690467048988083 ('meg', 'representantene') 75 1352 82
# ('meg', 'selv') wordtuple
# ('meg', 'selv') wordup
# 745.0 over
# 1499368.0 under
# -10.97482647109437 -9.541096615349524 1.1502688751142391 ('meg', 'selv') 745 1352 1109
# ('forslag', 'meg') wordtuple
# ('forslag', 'meg') wordup
# 643.0 over
# 1548040.0 under
# -11.233336391938543 -9.328674927327947 1.2041727768893493 ('forslag', 'meg') 643 1352 1145
# ('fremme', 'meg') wordtuple
# ('fremme', 'meg') wordup
# 129.0 over
# 214968.0 under
# -10.702535136143286 -7.011227255423254 1.5264852708724808 ('fremme', 'meg') 129 1352 159
# ('av', 'meg') wordtuple
# ('av', 'meg') wordup
# 8279.0 over
# 18365568.0 under
# -11.115259376502541 -13.015240803332683 0.8540187265422218 ('av', 'meg') 8279 1352 13584
# ('meg', 'om') wordtuple
# ('meg', 'om') wordup
# 6014.0 over
# 12739896.0 under
# -11.048741012081303 -12.554109152574002 0.8800896087330856 ('meg', 'om') 6014 1352 9423
# ('meg', 'representantforslag') wordtuple
# ('meg', 'representantforslag') wordup
# 24.0 over
# 32448.0 under
# -10.400879436282185 -4.584962500721157 2.2684764454772 ('meg', 'representantforslag') 24 1352 24
# ('meg', 'stortingsrepresentantene') wordtuple
# ('meg', 'stortingsrepresentantene') wordup
# 19.0 over
# 32448.0 under
# -10.737914423559756 -4.247927513443585 2.527800766274154 ('meg', 'stortingsrepresentantene') 19 1352 24
# ('representantene', 'selv') wordtuple
# ('representantene', 'selv') wordup
# 79.0 over
# 90938.0 under
# -10.168814906602691 -6.303780748177103 1.6131295349292185 ('representantene', 'selv') 79 82 1109
# ('forslag', 'representantene') wordtuple
# ('forslag', 'representantene') wordup
# 78.0 over
# 93890.0 under
# -10.233281668740142 -6.285402218862249 1.6281029140872576 ('forslag', 'representantene') 78 82 1145
# ('fremme', 'representantene') wordtuple
# ('fremme', 'representantene') wordup
# 19.0 over
# 13038.0 under
# -9.422507446458853 -4.247927513443585 2.218142239159936 ('fremme', 'representantene') 19 82 159
# ('av', 'representantene') wordtuple
# ('av', 'representantene') wordup
# 353.0 over
# 1113888.0 under
# -11.623648374899942 -8.46352437327118 1.3733815680390558 ('av', 'representantene') 353 82 13584
# ('om', 'representantene') wordtuple
# ('om', 'representantene') wordup
# 258.0 over
# 772686.0 under
# -11.548295477567951 -8.011227255423254 1.4415139040963112 ('om', 'representantene') 258 82 9423
# ('representantene', 'representantforslag') wordtuple
# ('representantene', 'representantforslag') wordup
# 10.0 over
# 1968.0 under
# -7.620586410451877 -3.3219280948873626 2.2940250940953226 ('representantene', 'representantforslag') 10 82 24
# ('representantene', 'stortingsrepresentantene') wordtuple
# ('forslag', 'selv') wordtuple
# ('forslag', 'selv') wordup
# 636.0 over
# 1269805.0 under
# -10.963292577861662 -9.312882955284357 1.17721790668923 ('forslag', 'selv') 636 1109 1145
# ('fremme', 'selv') wordtuple
# ('fremme', 'selv') wordup
# 136.0 over
# 176331.0 under
# -10.340463764195727 -7.08746284125034 1.458979608896476 ('fremme', 'selv') 136 1109 159
# ('av', 'selv') wordtuple
# ('av', 'selv') wordup
# 8539.0 over
# 15064656.0 under
# -10.784812982943945 -13.059851410770804 0.8257990572579889 ('av', 'selv') 8539 1109 13584
# ('om', 'selv') wordtuple
# ('om', 'selv') wordup
# 5760.0 over
# 10450107.0 under
# -10.825161282205157 -12.491853096329676 0.8665776965777622 ('om', 'selv') 5760 1109 9423
# ('representantforslag', 'selv') wordtuple
# ('representantforslag', 'selv') wordup
# 18.0 over
# 26616.0 under
# -10.530081149440555 -4.169925001442312 2.525244733609924 ('representantforslag', 'selv') 18 1109 24
# ('selv', 'stortingsrepresentantene') wordtuple
# ('selv', 'stortingsrepresentantene') wordup
# 20.0 over
# 26616.0 under
# -10.378078055995504 -4.321928094887363 2.4012611566287467 ('selv', 'stortingsrepresentantene') 20 1109 24
# ('forslag', 'fremme') wordtuple
# ('forslag', 'fremme') wordup
# 230.0 over
# 182055.0 under
# -9.628524787324286 -7.845490050944376 1.2272687524682138 ('forslag', 'fremme') 230 1145 159
# ('av', 'forslag') wordtuple
# ('av', 'forslag') wordup
# 7997.0 over
# 15553680.0 under
# -10.925509453980453 -12.965243172556892 0.8426767865878615 ('av', 'forslag') 7997 1145 13584
# ('forslag', 'om') wordtuple
# ('forslag', 'om') wordup
# 5446.0 over
# 10789335.0 under
# -10.95212134431363 -12.410981267043798 0.8824541032380707 ('forslag', 'om') 5446 1145 9423
# ('forslag', 'representantforslag') wordtuple
# ('forslag', 'representantforslag') wordup
# 13.0 over
# 27480.0 under
# -11.04565466556437 -3.700439718141092 2.984957331263629 ('forslag', 'representantforslag') 13 1145 24
# ('forslag', 'stortingsrepresentantene') wordtuple
# ('forslag', 'stortingsrepresentantene') wordup
# 26.0 over
# 27480.0 under
# -10.04565466556437 -4.700439718141093 2.1371733854587496 ('forslag', 'stortingsrepresentantene') 26 1145 24
# ('av', 'fremme') wordtuple
# ('av', 'fremme') wordup
# 1273.0 over
# 2159856.0 under
# -10.728486994936036 -10.314016703901359 1.0401851483213034 ('av', 'fremme') 1273 159 13584
# ('fremme', 'om') wordtuple
# ('fremme', 'om') wordup
# 768.0 over
# 1498257.0 under
# -10.92989118293632 -9.584962500721156 1.1403165304104188 ('fremme', 'om') 768 159 9423
# ('fremme', 'representantforslag') wordtuple
# ('fremme', 'representantforslag') wordup
# 6.0 over
# 3816.0 under
# -9.312882955284357 -2.584962500721156 3.6027149146984674 ('fremme', 'representantforslag') 6 159 24
# ('fremme', 'stortingsrepresentantene') wordtuple
# ('fremme', 'stortingsrepresentantene') wordup
# 8.0 over
# 3816.0 under
# -8.897845456005513 -3.0 2.9659484853351707 ('fremme', 'stortingsrepresentantene') 8 159 24
# ('av', 'om') wordtuple
# ('av', 'om') wordup
# 66499.0 over
# 128002032.0 under
# -10.91054644658827 -16.021045025337887 0.6810134063872132 ('av', 'om') 66499 13584 9423
# ('av', 'representantforslag') wordtuple
# ('av', 'representantforslag') wordup
# 114.0 over
# 326016.0 under
# -11.481693230109453 -6.832890014164742 1.6803568045596566 ('av', 'representantforslag') 114 13584 24
# ('av', 'stortingsrepresentantene') wordtuple
# ('av', 'stortingsrepresentantene') wordup
# 101.0 over
# 326016.0 under
# -11.6563717615224 -6.6582114827517955 1.750676107498 ('av', 'stortingsrepresentantene') 101 13584 24
# ('om', 'representantforslag') wordtuple
# ('om', 'representantforslag') wordup
# 71.0 over
# 226152.0 under
# -11.637186109589596 -6.149747119504682 1.8923031928712684 ('om', 'representantforslag') 71 9423 24
# ('om', 'stortingsrepresentantene') wordtuple
# ('om', 'stortingsrepresentantene') wordup
# 67.0 over
# 226152.0 under
# -11.720844038636507 -6.066089190457772 1.9321911812760544 ('om', 'stortingsrepresentantene') 67 9423 24
# ('representantforslag', 'stortingsrepresentantene') wordtuple
# ('representantforslag', 'stortingsrepresentantene') wordup
# 5.0 over
# 576.0 under
# -6.84799690655495 -2.321928094887362 2.9492717374123294 ('representantforslag', 'stortingsrepresentantene') 5 24 24
# 147.40358597608983 2v
# 90 x2
# 88
# 1.6378176219565537 n printed
# 10
# ('av', 'og') wordtuple
# ('av', 'og') wordup
# 240906.0 over
# 417381984.0 under
# -10.758682287828702 -17.87811080019439 0.6017795956221349 ('av', 'og') 240906 13584 30726
# ('av', 'for') wordtuple
# ('av', 'for') wordup
# 149947.0 over
# 262605888.0 under
# -10.774230890148026 -17.194093132832737 0.62662396945927 ('av', 'for') 149947 13584 19332
# ('av', 'til') wordtuple
# ('av', 'til') wordup
# 148774.0 over
# 269954832.0 under
# -10.825379904289203 -17.18276289504583 0.6300139256074121 ('av', 'til') 148774 13584 19873
# ('av', 'er') wordtuple
# ('av', 'er') wordup
# 241672.0 over
# 456259392.0 under
# -10.882588208568093 -17.88269080727902 0.608554290058989 ('av', 'er') 241672 13584 33588
# ('at', 'av') wordtuple
# ('at', 'av') wordup
# 188474.0 over
# 369267456.0 under
# -10.936084888950818 -17.524005991786442 0.6240630649222898 ('at', 'av') 188474 13584 27184
# ('av', 'har') wordtuple
# ('av', 'har') wordup
# 123665.0 over
# 241034496.0 under
# -10.928586676613428 -16.91607771710132 0.646047320151832 ('av', 'har') 123665 13584 17744
# ('av', 'en') wordtuple
# ('av', 'en') wordup
# 114400.0 over
# 202877040.0 under
# -10.792302834198077 -16.803727526553114 0.6422564765552267 ('av', 'en') 114400 13584 14935
# ('av', 'det') wordtuple
# ('av', 'det') wordup
# 294140.0 over
# 578773488.0 under
# -10.942280133026156 -18.166143463618013 0.6023446944003636 ('av', 'det') 294140 13584 42607
# ('av', 'med') wordtuple
# ('av', 'med') wordup
# 86469.0 over
# 159924432.0 under
# -10.85291973397223 -16.399895384411774 0.6617676198281126 ('av', 'med') 86469 13584 11773
# ('for', 'og') wordtuple
# ('for', 'og') wordup
# 339800.0 over
# 593995032.0 under
# -10.771549296938831 -18.374326326958943 0.5862282570400819 ('for', 'og') 339800 30726 19332
# ('og', 'til') wordtuple
# ('og', 'til') wordup
# 333862.0 over
# 610617798.0 under
# -10.83680202987262 -18.348892370379428 0.5905970677209075 ('og', 'til') 333862 30726 19873
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 30726 33588
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 30726 27184
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# ...
# ('at', 'ddsstraff') wordtuple
# ('de', 'representanten') wordtuple
# ('de', 'representanten') wordup
# 5664.0 over
# 15980058.0 under
# -11.462163758699843 -12.467605550082997 0.9193556623728395 ('de', 'representanten') 5664 1623 9846
# ('har', 'representanten') wordtuple
# ('har', 'representanten') wordup
# 10097.0 over
# 28798512.0 under
# -11.477851849117311 -13.301639085592372 0.8628900374803816 ('har', 'representanten') 10097 1623 17744
# ('ddsstraff', 'representanten') wordtuple
# ('de', 'har') wordtuple
# ('de', 'har') wordup
# 92031.0 over
# 174707424.0 under
# -10.890533390057756 -16.489832284338824 0.660439306008043 ('de', 'har') 92031 9846 17744
# ('ddsstraff', 'de') wordtuple
# ('ddsstraff', 'har') wordtuple
# 31.043531117990256 2v
# 90 x2
# 72
# 0.34492812353322505 n printed
# 10
# ('fremskrittspartiet', 'har') wordtuple
# ('fremskrittspartiet', 'har') wordup
# 16048.0 over
# 34831472.0 under
# -11.0837822170157 -13.970105890612182 0.7933928564180698 ('fremskrittspartiet', 'har') 16048 1963 17744
# ('fremskrittspartiet', 'som') wordtuple
# ('fremskrittspartiet', 'som') wordup
# 22423.0 over
# 48444877.0 under
# -11.07714908377782 -14.452691690501885 0.7664419418188776 ('fremskrittspartiet', 'som') 22423 1963 24679
# ('fra', 'fremskrittspartiet') wordtuple
# ('fra', 'fremskrittspartiet') wordup
# 4841.0 over
# 8020818.0 under
# -10.694228567338543 -12.241089378860858 0.8736337295115589 ('fra', 'fremskrittspartiet') 4841 1963 4086
# ('det', 'fremskrittspartiet') wordtuple
# ('det', 'fremskrittspartiet') wordup
# 36016.0 over
# 83637541.0 under
# -11.181296969103144 -15.136350341454156 0.7387049531009304 ('det', 'fremskrittspartiet') 36016 1963 42607
# ('er', 'fremskrittspartiet') wordtuple
# ('er', 'fremskrittspartiet') wordup
# 30093.0 over
# 65933244.0 under
# -11.097362412719336 -14.877140317040906 0.7459338405249797 ('er', 'fremskrittspartiet') 30093 1963 33588
# ('de', 'fremskrittspartiet') wordtuple
# ('de', 'fremskrittspartiet') wordup
# 11115.0 over
# 19327698.0 under
# -10.763946153786687 -13.440220327914352 0.8008757216152744 ('de', 'fremskrittspartiet') 11115 1963 9846
# ('fremskrittspartiet', 'og') wordtuple
# ('fremskrittspartiet', 'og') wordup
# 31104.0 over
# 60315138.0 under
# -10.92120429833044 -14.92481250360578 0.7317481741021482 ('fremskrittspartiet', 'og') 31104 1963 30726
# ('at', 'fremskrittspartiet') wordtuple
# ('at', 'fremskrittspartiet') wordup
# 25675.0 over
# 53362192.0 under
# -11.021237938557471 -14.648076656092922 0.752401710976379 ('at', 'fremskrittspartiet') 25675 1963 27184
# ('avgiftene', 'fremskrittspartiet') wordtuple
# ('avgiftene', 'fremskrittspartiet') wordup
# 36.0 over
# 72631.0 under
# -10.978372821652808 -5.169925001442312 2.1235071724618924 ('avgiftene', 'fremskrittspartiet') 36 1963 37
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 17744 24679
# ('fra', 'har') wordtuple
# ('fra', 'har') wordup
# 36074.0 over
# 72501984.0 under
# -10.972845356729833 -15.138671782165106 0.7248221980515464 ('fra', 'har') 36074 17744 4086
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 17744 42607
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 17744 33588
# ('de', 'har') wordtuple
# ('de', 'har') wordup
# 92031.0 over
# 174707424.0 under
# -10.890533390057756 -16.489832284338824 0.660439306008043 ('de', 'har') 92031 17744 9846
# ('har', 'og') wordtuple
# ('har', 'og') wordup
# 284599.0 over
# 545202144.0 under
# -10.903644927541992 -18.118571067089768 0.6017938659272732 ('har', 'og') 284599 17744 30726
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 17744 27184
# ('avgiftene', 'har') wordtuple
# ('avgiftene', 'har') wordup
# 213.0 over
# 656528.0 under
# -11.589787395564823 -7.734709620225839 1.4984127348825311 ('avgiftene', 'har') 213 17744 37
# ('fra', 'som') wordtuple
# ('fra', 'som') wordup
# 52820.0 over
# 100838394.0 under
# -10.898673124492307 -15.688796681054457 0.6946787153952586 ('fra', 'som') 52820 24679 4086
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 24679 42607
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 24679 33588
# ('de', 'som') wordtuple
# ('de', 'som') wordup
# 135583.0 over
# 242989434.0 under
# -10.807501568323241 -17.048816772725164 0.6339150518417894 ('de', 'som') 135583 24679 9846
# ('og', 'som') wordtuple
# ('og', 'som') wordup
# 414423.0 over
# 758286954.0 under
# -10.837424113684415 -18.660744547599172 0.5807605417908537 ('og', 'som') 414423 24679 30726
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 24679 27184
# ('avgiftene', 'som') wordtuple
# ('avgiftene', 'som') wordup
# 384.0 over
# 913123.0 under
# -11.215487181721329 -8.584962500721156 1.3064107363053947 ('avgiftene', 'som') 384 24679 37
# ('det', 'fra') wordtuple
# ('det', 'fra') wordup
# 86461.0 over
# 174092202.0 under
# -10.975514439866005 -16.399761901958353 0.6692484016219394 ('det', 'fra') 86461 4086 42607
# ('er', 'fra') wordtuple
# ('er', 'fra') wordup
# 69515.0 over
# 137240568.0 under
# -10.947095064207868 -16.08503669681943 0.680576318882287 ('er', 'fra') 69515 4086 33588
# ('de', 'fra') wordtuple
# ('de', 'fra') wordup
# 23821.0 over
# 40230756.0 under
# -10.721849154945485 -14.539946358022613 0.7374063762642122 ('de', 'fra') 23821 4086 9846
# ('fra', 'og') wordtuple
# ('fra', 'og') wordup
# 67383.0 over
# 125546436.0 under
# -10.863548792650754 -16.040097040552524 0.6772745055834489 ('fra', 'og') 67383 4086 30726
# ('at', 'fra') wordtuple
# ('at', 'fra') wordup
# 54048.0 over
# 111073824.0 under
# -11.004990013116062 -15.721953612801386 0.6999759879812518 ('at', 'fra') 54048 4086 27184
# ('avgiftene', 'fra') wordtuple
# ('avgiftene', 'fra') wordup
# 82.0 over
# 151182.0 under
# -10.848374849744093 -6.357552004618085 1.706376108581401 ('avgiftene', 'fra') 82 4086 37
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 42607 33588
# ('de', 'det') wordtuple
# ('de', 'det') wordup
# 216721.0 over
# 419508522.0 under
# -10.918645447298118 -17.725479430027878 0.6159859026888361 ('de', 'det') 216721 42607 9846
# ('det', 'og') wordtuple
# ('det', 'og') wordup
# 678738.0 over
# 1309142682.0 under
# -10.913479936643508 -19.372495260917674 0.5633492118416209 ('det', 'og') 678738 42607 30726
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 42607 27184
# ('avgiftene', 'det') wordtuple
# ('avgiftene', 'det') wordup
# 506.0 over
# 1576459.0 under
# -11.605262644025768 -8.98299357469431 1.2919148330149721 ('avgiftene', 'det') 506 42607 37
# ('de', 'er') wordtuple
# ('de', 'er') wordup
# 174949.0 over
# 330707448.0 under
# -10.884405403865689 -17.416574892663252 0.6249452301009398 ('de', 'er') 174949 33588 9846
# ('er', 'og') wordtuple
# ('er', 'og') wordup
# 554413.0 over
# 1032024888.0 under
# -10.862229055819636 -19.080601560944487 0.569281268262171 ('er', 'og') 554413 33588 30726
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 33588 27184
# ('avgiftene', 'er') wordtuple
# ('avgiftene', 'er') wordup
# 462.0 over
# 1242756.0 under
# -11.393362596506963 -8.851749041416058 1.2871312260660646 ('avgiftene', 'er') 462 33588 37
# ('de', 'og') wordtuple
# ('de', 'og') wordup
# 169125.0 over
# 302528196.0 under
# -10.804763960066294 -17.367730408638625 0.62211720851517 ('de', 'og') 169125 9846 30726
# ('at', 'de') wordtuple
# ('at', 'de') wordup
# 135063.0 over
# 267653664.0 under
# -10.952519179065026 -17.043272982354065 0.6426300388666446 ('at', 'de') 135063 9846 27184
# ('avgiftene', 'de') wordtuple
# ('avgiftene', 'de') wordup
# 192.0 over
# 364302.0 under
# -10.889812889142663 -7.584962500721156 1.4357108407730812 ('avgiftene', 'de') 192 9846 37
# ('at', 'og') wordtuple
# ('at', 'og') wordup
# 424579.0 over
# 835255584.0 under
# -10.941968991002648 -18.69567349065162 0.5852674415005135 ('at', 'og') 424579 30726 27184
# ('avgiftene', 'og') wordtuple
# ('avgiftene', 'og') wordup
# 385.0 over
# 1136862.0 under
# -11.527911074516737 -8.588714635582265 1.3422161014359062 ('avgiftene', 'og') 385 30726 37
# ('at', 'avgiftene') wordtuple
# ('at', 'avgiftene') wordup
# 373.0 over
# 1005808.0 under
# -11.396891682557932 -8.543031820255239 1.3340570329536041 ('at', 'avgiftene') 373 27184 37
# 73.97991115848468 2v
# 90 x2
# 90
# 0.821999012872052 n printed
# 10
# ('det', 'er') wordtuple
# ('det', 'er') wordup
# 760498.0 over
# 1431083916.0 under
# -10.877876197073403 -19.536584928311797 0.556795173618575 ('det', 'er') 760498 42607 33588
# ('det', 'vi') wordtuple
# ('det', 'vi') wordup
# 376531.0 over
# 687975229.0 under
# -10.83537225769542 -18.522409122083445 0.5849872004380298 ('det', 'vi') 376531 42607 16147
# ('det', 'har') wordtuple
# ('det', 'har') wordup
# 381971.0 over
# 756018608.0 under
# -10.95074291868161 -18.54310358457123 0.590556099130739 ('det', 'har') 381971 42607 17744
# ('det', 'ein') wordtuple
# ('det', 'ein') wordup
# 54309.0 over
# 102981119.0 under
# -10.888900932367061 -15.728903678489651 0.6922860712319305 ('det', 'ein') 54309 42607 2417
# ('at', 'det') wordtuple
# ('at', 'det') wordup
# 582267.0 over
# 1158228688.0 under
# -10.957951659534366 -19.151321330740984 0.5721773171830746 ('at', 'det') 582267 42607 27184
# ('det', 'men') wordtuple
# ('det', 'men') wordup
# 128423.0 over
# 240473908.0 under
# -10.870761045252515 -16.97054408043588 0.6405664422854087 ('det', 'men') 128423 42607 5644
# ('det', 'dette') wordtuple
# ('det', 'dette') wordup
# 142858.0 over
# 289599779.0 under
# -10.98526295715708 -17.124222303410846 0.6415043417749259 ('det', 'dette') 142858 42607 6797
# ('det', 'ogs') wordtuple
# ('det', 'som') wordtuple
# ('det', 'som') wordup
# 555051.0 over
# 1051498153.0 under
# -10.887538358119151 -19.082260811785517 0.5705580940071225 ('det', 'som') 555051 42607 24679
# ('er', 'vi') wordtuple
# ('er', 'vi') wordup
# 298629.0 over
# 542345436.0 under
# -10.826642051488284 -18.187994747493523 0.5952630953437182 ('er', 'vi') 298629 33588 16147
# ('er', 'har') wordtuple
# ('er', 'har') wordup
# 300100.0 over
# 595985472.0 under
# -10.955618129082769 -18.195083793373016 0.6021196853774867 ('er', 'har') 300100 33588 17744
# ('ein', 'er') wordtuple
# ('ein', 'er') wordup
# 39955.0 over
# 81182196.0 under
# -10.988571596071955 -15.286088433987699 0.7188609200794316 ('ein', 'er') 39955 33588 2417
# ('at', 'er') wordtuple
# ('at', 'er') wordup
# 460581.0 over
# 913056192.0 under
# -10.953033037091695 -18.8130953723866 0.5822025998533069 ('at', 'er') 460581 33588 27184
# ('er', 'men') wordtuple
# ('er', 'men') wordup
# 100283.0 over
# 189570672.0 under
# -10.884443009812395 -16.61371753507894 0.6551479514943299 ('er', 'men') 100283 33588 5644
# ('dette', 'er') wordtuple
# ('dette', 'er') wordup
# 118523.0 over
# 228297636.0 under
# -10.911533156622637 -16.85480752314823 0.6473840262866747 ('dette', 'er') 118523 33588 6797
# ('er', 'ogs') wordtuple
# ('er', 'som') wordtuple
# ('er', 'som') wordup
# 446353.0 over
# 828918252.0 under
# -10.858828992155898 -18.76782559695171 0.5785874839927967 ('er', 'som') 446353 33588 24679
# ('har', 'vi') wordtuple
# ('har', 'vi') wordup
# 159145.0 over
# 286512368.0 under
# -10.814039871159938 -17.279982305689508 0.6258131333617957 ('har', 'vi') 159145 16147 17744
# ('ein', 'vi') wordtuple
# ('ein', 'vi') wordup
# 17866.0 over
# 39027299.0 under
# -11.093051237850839 -14.12492904660248 0.7853527052243204 ('ein', 'vi') 17866 16147 2417
# ('at', 'vi') wordtuple
# ('at', 'vi') wordup
# 232152.0 over
# 438940048.0 under
# -10.884738479593876 -17.82471018427808 0.610654443582176 ('at', 'vi') 232152 16147 27184
# ('men', 'vi') wordtuple
# ('men', 'vi') wordup
# 51070.0 over
# 91133668.0 under
# -10.80129236068522 -15.640188438599779 0.6906113953223079 ('men', 'vi') 51070 16147 5644
# ('dette', 'vi') wordtuple
# ('dette', 'vi') wordup
# 58288.0 over
# 109751159.0 under
# -10.878749654421748 -15.830911279742782 0.6871840453267011 ('dette', 'vi') 58288 16147 6797
# ('ogs', 'vi') wordtuple
# ('som', 'vi') wordtuple
# ('som', 'vi') wordup
# 221603.0 over
# 398491813.0 under
# -10.812356956739512 -17.75761788676176 0.6088855512990897 ('som', 'vi') 221603 16147 24679
# ('ein', 'har') wordtuple
# ('ein', 'har') wordup
# 21597.0 over
# 42887248.0 under
# -10.955502104216505 -14.398543303710788 0.7608757270183752 ('ein', 'har') 21597 17744 2417
# ('at', 'har') wordtuple
# ('at', 'har') wordup
# 237473.0 over
# 482352896.0 under
# -10.988109820435762 -17.85740396691017 0.6153251525695878 ('at', 'har') 237473 17744 27184
# ('har', 'men') wordtuple
# ('har', 'men') wordup
# 51069.0 over
# 100147136.0 under
# -10.937385733800195 -15.640160188958781 0.6993141759201082 ('har', 'men') 51069 17744 5644
# ('dette', 'har') wordtuple
# ('dette', 'har') wordup
# 59458.0 over
# 120605968.0 under
# -10.9861427422335 -15.859583315405008 0.6927132020903883 ('dette', 'har') 59458 17744 6797
# ('har', 'ogs') wordtuple
# ('har', 'som') wordtuple
# ('har', 'som') wordup
# 228665.0 over
# 437904176.0 under
# -10.9031639321698 -17.802876034805447 0.6124383448412273 ('har', 'som') 228665 17744 24679
# ('at', 'ein') wordtuple
# ('at', 'ein') wordup
# 32868.0 over
# 65703728.0 under
# -10.96507584352327 -15.004396051426534 0.7307908832812215 ('at', 'ein') 32868 2417 27184
# ('ein', 'men') wordtuple
# ('ein', 'men') wordup
# 7393.0 over
# 13641548.0 under
# -10.849559832363347 -12.851944197999499 0.8441959959686226 ('ein', 'men') 7393 2417 5644
# ('dette', 'ein') wordtuple
# ('dette', 'ein') wordup
# 6844.0 over
# 16428349.0 under
# -11.229060120752965 -12.740624044489413 0.8813587216404654 ('dette', 'ein') 6844 2417 6797
# ('ein', 'ogs') wordtuple
# ('ein', 'som') wordtuple
# ('ein', 'som') wordup
# 29723.0 over
# 59649143.0 under
# -10.970705957797362 -14.859292116781758 0.7383060963857954 ('ein', 'som') 29723 2417 24679
# ('at', 'men') wordtuple
# ('at', 'men') wordup
# 75897.0 over
# 153426496.0 under
# -10.981217169237674 -16.211755240543813 0.6773613964868443 ('at', 'men') 75897 27184 5644
# ('at', 'dette') wordtuple
# ('at', 'dette') wordup
# 93095.0 over
# 184769648.0 under
# -10.954736480344833 -16.506416064316188 0.6636653551964525 ('at', 'dette') 93095 27184 6797
# ('at', 'ogs') wordtuple
# ('at', 'som') wordtuple
# ('at', 'som') wordup
# 339600.0 over
# 670873936.0 under
# -10.947989520669992 -18.373476933327765 0.5958583430015559 ('at', 'som') 339600 27184 24679
# ('dette', 'men') wordtuple
# ('dette', 'men') wordup
# 19296.0 over
# 38362268.0 under
# -10.957170488173977 -14.236014191900084 0.7696796547455198 ('dette', 'men') 19296 5644 6797
# ('men', 'ogs') wordtuple
# ('men', 'som') wordtuple
# ('men', 'som') wordup
# 73188.0 over
# 139288276.0 under
# -10.894179088123753 -16.159319501287044 0.6741731350293595 ('men', 'som') 73188 5644 24679
# ('dette', 'ogs') wordtuple
# ('dette', 'som') wordtuple
# ('dette', 'som') wordup
# 87192.0 over
# 167743163.0 under
# -10.90977057315369 -16.411908151136643 0.6647472355247193 ('dette', 'som') 87192 6797 24679
# ('ogs', 'som') wordtuple
# 29.716602391828363 2v
# 90 x2
# 72
# 0.3301844710203152 n printed
# [0.6336180451659053, 0.6034419300674064, 0.6505325385818375, 0.2963520757524209, 0.6070029657621864, 1.6378176219565537, 0.6115168554953597, 1.5519742862168413, 0.6129986399700875, 0.6055285937915843, 0.7343276380179989, 0.6034419300674061, 0.70949420980899, 0.6538272624625308, 0.7125618811369608, 0.6179234529351252, 0.6386371378512303, 0.7449393489491466, 0.6107639444401592, 0.670472938565501, 0.7623032960647925, 0.6846433490454208, -0.5090701965527917, 0.6948144238760589, 0.6732140548752377, 0.2900051195216878, 0.8678130917804452, 0.9463547003398636, 0.6962590480204746, 0.4817695447034295, 0.985228817774691, 0.29825256629788394, 0.82590283658369, 0.4622532095117621, 0.34492812353322505, 0.821999012872052, 0.3301844710203152] npmis

# %%
from nltk import word_tokenize
from utils.config import use_pmi
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary
if not use_pmi:
    corpus_tokenized = []
    for item in new_data:
        word_tokens = word_tokenize(item)
        corpus_tokenized.append(word_tokens)

    dct = Dictionary(corpus_tokenized)
    inp = list(loaded_topics.values())


    cm = CoherenceModel(topics=inp, texts = corpus_tokenized, dictionary=dct, coherence='c_npmi')
    coherence2 = cm.get_coherence()  # get coherence value
    print(coherence2)
# Out:
# -0.017084601102097825

# %%
print(diversity)
# Out:
# 0.24594594594594596

# %%
print(coherence)
# Out:
# 0.6530818585476613

# %%
from tabulate import tabulate
import csv

# %%
# Check the stats for the dataset after running basic pipeline

models = [file_name for i in range(0, 2)]
metrics = ["coherence" if i < 1 else "diversity" for i in range(0, 2)]
values = [
    coherence,
    diversity
    ]

stats = [models, metrics, values]
stats_tabulate = list(zip(*stats))
print(tabulate(stats_tabulate, headers=["Model", "Metric", "Value"], tablefmt="fancy_grid"))
# Out:
# ╒══════════════════════════════════╤═══════════╤══════════╕
# │ Model                            │ Metric    │    Value │
# ╞══════════════════════════════════╪═══════════╪══════════╡
# │ bertopic_preliminary_np_mini_raw │ coherence │ 0.653082 │
# ├──────────────────────────────────┼───────────┼──────────┤
# │ bertopic_preliminary_np_mini_raw │ diversity │ 0.245946 │
# ╘══════════════════════════════════╧═══════════╧══════════╛

# %%
# Save all topic stats to file

topic_stats_folder_path = f"preprocessed_data/metrics/{model_type}"
topic_stats_file_name = f"{file_name}_stats"
topic_stats_path = os.path.join(ROOT_PATH,topic_stats_folder_path, topic_stats_file_name + r".csv")

TOPIC_STAT = "Topic stat"
VALUE = "Value"

with open(topic_stats_path, encoding="utf-8", mode="w", newline="") as topic_stats_file:
    header = [TOPIC_STAT, VALUE]
    writer = csv.DictWriter(topic_stats_file, fieldnames=header, delimiter=";")
    writer.writeheader()
    writer.writerow({TOPIC_STAT : "Coherence", VALUE : coherence})
    writer.writerow({TOPIC_STAT : "Diversity", VALUE : diversity})
